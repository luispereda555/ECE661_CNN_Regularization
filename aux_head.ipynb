# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys 
sys.path.append('/content/drive/MyDrive/ECE_661/661_Final_Project')

# %%
# import necessary dependencies
import argparse
import os
import time
import tools
import datetime
from tqdm import tqdm_notebook as tqdm

from tools import opencv_functional as cv2
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import itertools

# %%
# define the ResBlock to be used in ResNet;
class ResBlock(nn.Module):
    def __init__(self, input_dim, output_dim, k_size=3, stride_bool=False):
        super(ResBlock, self).__init__()
        if(stride_bool == True):
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, stride=2, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1, stride=2)
        else:
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1)

        if input_dim != output_dim:
          input_dim = output_dim
        self.bn1 = nn.BatchNorm2d(output_dim)
        self.conv2 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
        self.bn2 = nn.BatchNorm2d(output_dim)

    def forward(self, x):
        y = x
      # Note shortcut will just be x if of same shape as out
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out)) 
        if (x.shape == out.shape):
          out = out + y
          out = F.relu(out)
          return out
        else:
          y = self.resconv(y)
          out = out.add(y)
          out = F.relu(out)
          return out

# %%
class ResNet(nn.Module):
  def __init__(self):
    super(ResNet, self).__init__()
    self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
    self.bn1 = nn.BatchNorm2d(16)
    # 16 filter res blockss
    self.res1 = ResBlock(16, 16)
    self.res2 = ResBlock(16, 16)
    self.res3 = ResBlock(16, 16)
    # Now 32 filter res blocks
    self.res4 = ResBlock(16, 32, stride_bool=True)
    self.res5 = ResBlock(32, 32)
    self.res6 = ResBlock(32, 32)
    # Now 64 filter res blocks 
    self.res7 = ResBlock(32, 64, stride_bool=True)
    self.res8 = ResBlock(64, 64)
    self.res9 = ResBlock(64, 64)

    self.fc = nn.Linear(64, 10)
    self.fc2 = nn.Linear(64,4)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))

    # ReLU contained within forward method of res blocks
    
    out = self.res1(out)
    out = self.res2(out)
    out = self.res3(out)

    out = self.res4(out)
    out = self.res5(out)
    out = self.res6(out)

    out = self.res7(out)
    out = self.res8(out)
    out = self.res9(out)

    out = F.adaptive_avg_pool2d(out, 1)
    out = out.view(out.size(0), -1)
    outt = self.fc(out)
    outr = self.fc2(out)
    # out = F.softmax(out)
    return outt, outr

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010)),
                                      transforms.RandomCrop(size=(32,32), padding=4),
                                      # transforms.RandomHorizontalFlip(), 
                                      transforms.RandomRotation(degrees=15)]) 
                                      # transforms.GaussianBlur(kernel_size=5, sigma = 0.5)])

transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))])
#############################################

# %%
# do NOT change these
#import tools
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train    # your code
)
val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val    # your code
)


# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size=128,  # your code
    shuffle=True,     # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set, 
    batch_size=128,  # your code
    shuffle=False,     # your code
    num_workers=4
)
#############################################
# Out:
# Downloading https://www.dropbox.com/s/s8orza214q45b23/cifar10_trainval_F22.zip?dl=1 to ./data/cifar10_trainval_F22.zip
# 0it [00:00, ?it/s]
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")
# Out:
# Run on GPU...

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

net = ResNet().to(device)
# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-5

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss().to(device)

# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay = REG) #momentum value from AlexNet
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities?)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %%
print('code below is stuff for initial loss, can add back in later if I feel like it, but honestly fuck it')

# # Calculate initial loss 
# initial_loss = 0
# for batch_idx, (inputs, targets) in enumerate(train_loader):
#   inputs = inputs.to(device)
#   targets = targets.to(device)
#   # print(targets.shape)
#   # print(inputs.shape)

#   # print(max(targets[:,0,0])) #this is the target for the label / classification
#   # print(max(targets[:,0,1])) # this is the target for the rotation amount - i.e will be 0 for 0,1, one for 1,1 two for 2,1, three for 3,1
#   output0 = net(inputs[:,0,:,:,:]) #this is output of unrotated image - change 0 to 1 for 90, 0 to 2 for 180, 0 to 3 for 270 
#   # compute the output and loss
#   # outputs = net(inputs[:,:3,:,:])[0]
#   initial_loss = criterion(output0[0], targets[:,0,0]) #this should just be initial classification loss 
#   # initial_loss += loss
# print("Initial loss: %.4f" %(initial_loss))
# Out:
# code below is stuff for initial loss, can add back in later if I feel like it, but honestly fuck it

# %% [markdown]
# ## Only data augmentation

# %%
# Just data augmentation
lam = 0.5
# some hyperparameters
# total number of training epochs
EPOCHS = 200
 
# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):

    if 140 > i > 100  :
      current_learning_rate = 0.1
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
      print("Current learning rate has decayed to %f" %current_learning_rate)
    if 170 > i > 140  :
      current_learning_rate = 0.001
      momentum = 0.6
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
          param_group['momentum'] = momentum
      print("Current learning rate has decayed to %f" %current_learning_rate)
    if i > 170  :
      current_learning_rate = 0.0005
      momentum = 0.3
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
          param_group['momentum'] = momentum
      print("Current learning rate has decayed to %f" %current_learning_rate)
    
    
    #######################
    # your code here
    # switch to train mode
    net.train()
    #######################

    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (bx, by) in enumerate(train_loader):
        ####################################
        # your code here

        bx = bx.to(device)
        by = by.to(device) # RIGHT HERE WE COULD CHANGE THIS, THEN WOULD BE IDENTICAL TO THERES, WHERE WE WOUDLN'T NEED TO DETACH OUR BX BEFORE - BUT historically we have been doing input = input.to(device)
        # SO I cam keeping it the way we used to for nostalgias sake


        # We are lifting the mthod of doing this directly from hendryx adversarial folder, the train.py file - we tried implementing it in three other ways but all lead to horrible overfitting 
        # This is the last appraoch we could find in hyndrex
        curr_batch_size = bx.size(0)
      
        
        by_prime = torch.cat((torch.zeros(bx.size(0)), torch.ones(bx.size(0)), 2*torch.ones(bx.size(0)), 3*torch.ones(bx.size(0))), 0).long()
        
        bx = bx.cpu().detach().numpy() #only change was here, as our stuff was already on GPU so heeded to detach
        
        bx = np.concatenate((bx, bx, np.rot90(bx, 1, axes=(2,3)), np.rot90(bx, 2, axes = (2,3)), np.rot90(bx, 3, axes =(2,3))), 0)
        
        bx = torch.FloatTensor(bx)
        
        bx, by_prime = bx.cuda(), by_prime.cuda()


        #now we are doing our forward - we don't have a scheduler like them, so no scheduler.step() 
        #also we zero our gradient later bc we are just hard bodied like that 

        logits, pen = net(bx*2-1)
        
        loss = criterion(logits[:curr_batch_size], by)
        loss += lam*.25 * criterion(pen[curr_batch_size:], by_prime)
      
        # compute the output and loss
       
        train_loss += loss
        # zero the gradient
        optimizer.zero_grad()

        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        # _, predicted = torch.max(output0[0], 1)
        _, predicted = torch.max(logits[:curr_batch_size], 1)
        # correct = predicted.eq(targets[:,0, 0]).sum()
        correct = predicted.eq(by).sum() #looking at correct labels

        total_examples += by.shape[0]
        correct_examples += correct.item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # compute the output and loss
            outputs = net(inputs)[0]
            val_loss += criterion(outputs, targets)
            
            # count the number of correctly predicted samples in the current batch
            _, predicted = torch.max(outputs, 1)
            correct = predicted.eq(targets).sum()

            total_examples += targets.shape[0]
            correct_examples += correct.item()
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_FOLDER):
           os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': net.state_dict(),
                'epoch': i,
                'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'resnet_base.pth'))
        # model.load_state_dict(state_dict["state_dict"])
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.8546, Training accuracy: 0.3611
# Validation loss: 2.1465, Validation accuracy: 0.2360
# Saving ...
#
# Epoch 1:
# Training loss: 1.4393, Training accuracy: 0.5300
# Validation loss: 1.9499, Validation accuracy: 0.3602
# Saving ...
#
# Epoch 2:
# Training loss: 1.2063, Training accuracy: 0.6194
# Validation loss: 1.8367, Validation accuracy: 0.4158
# Saving ...
#
# Epoch 3:
# Training loss: 1.0536, Training accuracy: 0.6749
# Validation loss: 1.1964, Validation accuracy: 0.5768
# Saving ...
#
# Epoch 4:
# Training loss: 0.9535, Training accuracy: 0.7078
# Validation loss: 1.4606, Validation accuracy: 0.5208
#
# Epoch 5:
# Training loss: 0.2157, Training accuracy: 0.9506
# Validation loss: 0.8591, Validation accuracy: 0.7676
#
# Current learning rate has decayed to 0.100000
# Epoch 104:
# Training loss: 0.2236, Training accuracy: 0.9475
# Validation loss: 1.1926, Validation accuracy: 0.7130
#
# Current learning rate has decayed to 0.100000
# Epoch 105:
# Training loss: 0.2139, Training accuracy: 0.9508
# Validation loss: 0.9622, Validation accuracy: 0.7632
#
# Current learning rate has decayed to 0.100000
# Epoch 106:
# Training loss: 0.2123, Training accuracy: 0.9525
# Validation loss: 0.9667, Validation accuracy: 0.7490
#
# Current learning rate has decayed to 0.100000
# Epoch 107:
# Training loss: 0.2113, Training accuracy: 0.9512
# Validation loss: 1.1878, Validation accuracy: 0.7130
#
# Current learning rate has decayed to 0.100000
# Epoch 108:
# Training loss: 0.2178, Training accuracy: 0.9501
# Validation loss: 0.7559, Validation accuracy: 0.7954
# Saving ...
#
# Current learning rate has decayed to 0.100000
# Epoch 109:
# Training loss: 0.2149, Training accuracy: 0.9512
# Validation loss: 1.2749, Validation accuracy: 0.6928
#
# Current learning rate has decayed to 0.100000
# Epoch 110:
# Training loss: 0.2155, Training accuracy: 0.9506
# Validation loss: 0.9066, Validation accuracy: 0.7540
#
# Current learning rate has decayed to 0.100000
# Epoch 111:
# Training loss: 0.2087, Training accuracy: 0.9540
# Validation loss: 1.0333, Validation accuracy: 0.7460
#
# Current learning rate has decayed to 0.100000
# Epoch 112:
# Training loss: 0.2050, Training accuracy: 0.9541
# Validation loss: 0.8165, Validation accuracy: 0.7840
#
# Current learning rate has decayed to 0.100000
# Epoch 113:
# Training loss: 0.2091, Training accuracy: 0.9540
# Validation loss: 0.9323, Validation accuracy: 0.7494
#
# Current learning rate has decayed to 0.100000
# Epoch 114:
# Training loss: 0.2104, Training accuracy: 0.9533
# Validation loss: 0.8541, Validation accuracy: 0.7748
#
# Current learning rate has decayed to 0.100000
# Epoch 115:
# Training loss: 0.2010, Training accuracy: 0.9551
# Validation loss: 0.8638, Validation accuracy: 0.7800
#
# Current learning rate has decayed to 0.100000
# Epoch 116:
# Training loss: 0.2036, Training accuracy: 0.9533
# Validation loss: 0.9122, Validation accuracy: 0.7804
#
# Current learning rate has decayed to 0.100000
# Epoch 117:
# Training loss: 0.2048, Training accuracy: 0.9552
# Validation loss: 0.9920, Validation accuracy: 0.7628
#
# Current learning rate has decayed to 0.100000
# Epoch 118:
# Training loss: 0.2108, Training accuracy: 0.9529
# Validation loss: 0.9984, Validation accuracy: 0.7574
#
# Current learning rate has decayed to 0.100000
# Epoch 119:
# Training loss: 0.2022, Training accuracy: 0.9556
# Validation loss: 0.9980, Validation accuracy: 0.7606
#
# Current learning rate has decayed to 0.100000
# Epoch 120:
# Training loss: 0.2062, Training accuracy: 0.9540
# Validation loss: 0.8574, Validation accuracy: 0.7714
#
# Current learning rate has decayed to 0.100000
# Epoch 121:
# Training loss: 0.1998, Training accuracy: 0.9559
# Validation loss: 0.9799, Validation accuracy: 0.7418
#
# Current learning rate has decayed to 0.100000
# Epoch 122:
# Training loss: 0.1994, Training accuracy: 0.9557
# Validation loss: 1.0260, Validation accuracy: 0.7322
#
# Current learning rate has decayed to 0.100000
# Epoch 123:
# Training loss: 0.2009, Training accuracy: 0.9551
# Validation loss: 0.8403, Validation accuracy: 0.7784
#
# Current learning rate has decayed to 0.100000
# Epoch 124:
# Training loss: 0.2001, Training accuracy: 0.9563
# Validation loss: 0.8389, Validation accuracy: 0.7800
#
# Current learning rate has decayed to 0.100000
# Epoch 125:
# Training loss: 0.1941, Training accuracy: 0.9580
# Validation loss: 0.8269, Validation accuracy: 0.7814
#
# Current learning rate has decayed to 0.100000
# Epoch 126:
# Training loss: 0.1963, Training accuracy: 0.9571
# Validation loss: 1.1889, Validation accuracy: 0.7084
#
# Current learning rate has decayed to 0.100000
# Epoch 127:
# Training loss: 0.1983, Training accuracy: 0.9567
# Validation loss: 1.1256, Validation accuracy: 0.7476
#
# Current learning rate has decayed to 0.100000
# Epoch 128:
# Training loss: 0.1987, Training accuracy: 0.9568
# Validation loss: 0.9912, Validation accuracy: 0.7532
#
# Current learning rate has decayed to 0.100000
# Epoch 129:
# Training loss: 0.2013, Training accuracy: 0.9557
# Validation loss: 1.0327, Validation accuracy: 0.7438
#
# Current learning rate has decayed to 0.100000
# Epoch 130:
# Training loss: 0.1967, Training accuracy: 0.9567
# Validation loss: 1.2486, Validation accuracy: 0.7084
#
# Current learning rate has decayed to 0.100000
# Epoch 131:
# Training loss: 0.2000, Training accuracy: 0.9552
# Validation loss: 0.8776, Validation accuracy: 0.7836
#
# Current learning rate has decayed to 0.100000
# Epoch 132:
# Training loss: 0.1972, Training accuracy: 0.9576
# Validation loss: 0.8241, Validation accuracy: 0.7842
#
# Current learning rate has decayed to 0.100000
# Epoch 133:
# Training loss: 0.1910, Training accuracy: 0.9587
# Validation loss: 1.1445, Validation accuracy: 0.7188
#
# Current learning rate has decayed to 0.100000
# Epoch 134:
# Training loss: 0.1948, Training accuracy: 0.9572
# Validation loss: 1.1087, Validation accuracy: 0.7332
#
# Current learning rate has decayed to 0.100000
# Epoch 135:
# Training loss: 0.1916, Training accuracy: 0.9589
# Validation loss: 0.9737, Validation accuracy: 0.7502
#
# Current learning rate has decayed to 0.100000
# Epoch 136:
# Training loss: 0.1910, Training accuracy: 0.9585
# Validation loss: 0.9775, Validation accuracy: 0.7584
#
# Current learning rate has decayed to 0.100000
# Epoch 137:
# Training loss: 0.1946, Training accuracy: 0.9576
# Validation loss: 0.8388, Validation accuracy: 0.7776
#
# Current learning rate has decayed to 0.100000
# Epoch 138:
# Training loss: 0.1927, Training accuracy: 0.9586
# Validation loss: 0.9978, Validation accuracy: 0.7466
#
# Current learning rate has decayed to 0.100000
# Epoch 139:
# Training loss: 0.1882, Training accuracy: 0.9595
# Validation loss: 1.0594, Validation accuracy: 0.7544
#
# Epoch 140:
# Training loss: 0.1924, Training accuracy: 0.9588
# Validation loss: 1.0276, Validation accuracy: 0.7462
#
# Current learning rate has decayed to 0.001000
# Epoch 141:
# Training loss: 0.1710, Training accuracy: 0.9654
# Validation loss: 0.9807, Validation accuracy: 0.7604
#
# Current learning rate has decayed to 0.001000
# Epoch 142:
# Training loss: 0.1652, Training accuracy: 0.9680
# Validation loss: 0.9518, Validation accuracy: 0.7692
#
# Current learning rate has decayed to 0.001000
# Epoch 143:
# Training loss: 0.1604, Training accuracy: 0.9698
# Validation loss: 0.9460, Validation accuracy: 0.7670
#
# Current learning rate has decayed to 0.001000
# Epoch 144:
# Training loss: 0.1570, Training accuracy: 0.9703
# Validation loss: 0.9612, Validation accuracy: 0.7644
#
# Current learning rate has decayed to 0.001000
# Epoch 145:
# Training loss: 0.1548, Training accuracy: 0.9718
# Validation loss: 0.9008, Validation accuracy: 0.7782
#
# Current learning rate has decayed to 0.001000
# Epoch 146:
# Training loss: 0.1531, Training accuracy: 0.9724
# Validation loss: 0.9314, Validation accuracy: 0.7698
#
# Current learning rate has decayed to 0.001000
# Epoch 147:
# Training loss: 0.1526, Training accuracy: 0.9722
# Validation loss: 0.9221, Validation accuracy: 0.7702
#
# Current learning rate has decayed to 0.001000
# Epoch 148:
# Training loss: 0.1496, Training accuracy: 0.9741
# Validation loss: 0.9276, Validation accuracy: 0.7694
#
# Current learning rate has decayed to 0.001000
# Epoch 149:
# Training loss: 0.1454, Training accuracy: 0.9755
# Validation loss: 0.9135, Validation accuracy: 0.7710
#
# Current learning rate has decayed to 0.001000
# Epoch 150:
# Training loss: 0.1439, Training accuracy: 0.9755
# Validation loss: 0.9122, Validation accuracy: 0.7696
#
# Current learning rate has decayed to 0.001000
# Epoch 151:
# Training loss: 0.1442, Training accuracy: 0.9752
# Validation loss: 0.8887, Validation accuracy: 0.7754
#
# Current learning rate has decayed to 0.001000
# Epoch 152:
# Training loss: 0.1453, Training accuracy: 0.9752
# Validation loss: 0.8940, Validation accuracy: 0.7760
#
# Current learning rate has decayed to 0.001000
# Epoch 153:
# Training loss: 0.1438, Training accuracy: 0.9753
# Validation loss: 0.8828, Validation accuracy: 0.7764
#
# Current learning rate has decayed to 0.001000
# Epoch 154:
# Training loss: 0.1406, Training accuracy: 0.9764
# Validation loss: 0.8897, Validation accuracy: 0.7774
#
# Current learning rate has decayed to 0.001000
# Epoch 155:
# Training loss: 0.1397, Training accuracy: 0.9766
# Validation loss: 0.8864, Validation accuracy: 0.7740
#
# Current learning rate has decayed to 0.001000
# Epoch 156:
# Training loss: 0.1424, Training accuracy: 0.9756
# Validation loss: 0.8710, Validation accuracy: 0.7804
#
# Current learning rate has decayed to 0.001000
# Epoch 157:
# Training loss: 0.1384, Training accuracy: 0.9772
# Validation loss: 0.9117, Validation accuracy: 0.7708
#
# Current learning rate has decayed to 0.001000
# Epoch 158:
# Training loss: 0.1372, Training accuracy: 0.9774
# Validation loss: 0.8764, Validation accuracy: 0.7776
#
# Current learning rate has decayed to 0.001000
# Epoch 159:
# Training loss: 0.1382, Training accuracy: 0.9779
# Validation loss: 0.8686, Validation accuracy: 0.7794
#
# Current learning rate has decayed to 0.001000
# Epoch 160:
# Training loss: 0.1378, Training accuracy: 0.9775
# Validation loss: 0.8483, Validation accuracy: 0.7864
#
# Current learning rate has decayed to 0.001000
# Epoch 161:
# Training loss: 0.1346, Training accuracy: 0.9790
# Validation loss: 0.8501, Validation accuracy: 0.7852
#
# Current learning rate has decayed to 0.001000
# Epoch 162:
# Training loss: 0.1362, Training accuracy: 0.9775
# Validation loss: 0.8634, Validation accuracy: 0.7838
#
# Current learning rate has decayed to 0.001000
# Epoch 163:
# Training loss: 0.1354, Training accuracy: 0.9783
# Validation loss: 0.8808, Validation accuracy: 0.7776
#
# Current learning rate has decayed to 0.001000
# Epoch 164:
# Training loss: 0.1357, Training accuracy: 0.9783
# Validation loss: 0.8762, Validation accuracy: 0.7808
#
# Current learning rate has decayed to 0.001000
# Epoch 165:
# Training loss: 0.1329, Training accuracy: 0.9797
# Validation loss: 0.8659, Validation accuracy: 0.7806
#
# Current learning rate has decayed to 0.001000
# Epoch 166:
# Training loss: 0.1330, Training accuracy: 0.9796
# Validation loss: 0.8825, Validation accuracy: 0.7798
#
# Current learning rate has decayed to 0.001000
# Epoch 167:
# Training loss: 0.1322, Training accuracy: 0.9794
# Validation loss: 0.8773, Validation accuracy: 0.7816
#
# Current learning rate has decayed to 0.001000
# Epoch 168:
# Training loss: 0.1346, Training accuracy: 0.9781
# Validation loss: 0.8664, Validation accuracy: 0.7826
#
# Current learning rate has decayed to 0.001000
# Epoch 169:
# Training loss: 0.1317, Training accuracy: 0.9793
# Validation loss: 0.8632, Validation accuracy: 0.7826
#
# Epoch 170:
# Training loss: 0.1310, Training accuracy: 0.9802
# Validation loss: 0.8510, Validation accuracy: 0.7858
#
# Current learning rate has decayed to 0.000500
# Epoch 171:
# Training loss: 0.1311, Training accuracy: 0.9792
# Validation loss: 0.8500, Validation accuracy: 0.7848
#
# Current learning rate has decayed to 0.000500
# Epoch 172:
# Training loss: 0.1317, Training accuracy: 0.9797
# Validation loss: 0.8470, Validation accuracy: 0.7866
#
# Current learning rate has decayed to 0.000500
# Epoch 173:
# Training loss: 0.1308, Training accuracy: 0.9801
# Validation loss: 0.8528, Validation accuracy: 0.7860
#
# Current learning rate has decayed to 0.000500
# Epoch 174:
# Training loss: 0.1316, Training accuracy: 0.9794
# Validation loss: 0.8407, Validation accuracy: 0.7870
#
# Current learning rate has decayed to 0.000500
# Epoch 175:
# Training loss: 0.1307, Training accuracy: 0.9802
# Validation loss: 0.8646, Validation accuracy: 0.7816
#
# Current learning rate has decayed to 0.000500
# Epoch 176:
# Training loss: 0.1310, Training accuracy: 0.9797
# Validation loss: 0.8657, Validation accuracy: 0.7824
#
# Current learning rate has decayed to 0.000500
# Epoch 177:
# Training loss: 0.1318, Training accuracy: 0.9800
# Validation loss: 0.8307, Validation accuracy: 0.7880
#
# Current learning rate has decayed to 0.000500
# Epoch 178:
# Training loss: 0.1326, Training accuracy: 0.9788
# Validation loss: 0.8449, Validation accuracy: 0.7850
#
# Current learning rate has decayed to 0.000500
# Epoch 179:
# Training loss: 0.1299, Training accuracy: 0.9806
# Validation loss: 0.8577, Validation accuracy: 0.7842
#
# Current learning rate has decayed to 0.000500
# Epoch 180:
# Training loss: 0.1314, Training accuracy: 0.9798
# Validation loss: 0.8522, Validation accuracy: 0.7858
#
# Current learning rate has decayed to 0.000500
# Epoch 181:
# Training loss: 0.1299, Training accuracy: 0.9797
# Validation loss: 0.8574, Validation accuracy: 0.7838
#
# Current learning rate has decayed to 0.000500
# Epoch 182:
# Training loss: 0.1302, Training accuracy: 0.9806
# Validation loss: 0.8709, Validation accuracy: 0.7818
#
# Current learning rate has decayed to 0.000500
# Epoch 183:
# Training loss: 0.1325, Training accuracy: 0.9792
# Validation loss: 0.8301, Validation accuracy: 0.7900
#
# Current learning rate has decayed to 0.000500
# Epoch 184:
# Training loss: 0.1307, Training accuracy: 0.9798
# Validation loss: 0.9009, Validation accuracy: 0.7766
#
# Current learning rate has decayed to 0.000500
# Epoch 185:
# Training loss: 0.1318, Training accuracy: 0.9797
# Validation loss: 0.8689, Validation accuracy: 0.7816
#
# Current learning rate has decayed to 0.000500
# Epoch 186:
# Training loss: 0.1303, Training accuracy: 0.9794
# Validation loss: 0.8564, Validation accuracy: 0.7826
#
# Current learning rate has decayed to 0.000500
# Epoch 187:
# Training loss: 0.1303, Training accuracy: 0.9797
# Validation loss: 0.8503, Validation accuracy: 0.7834
#
# Current learning rate has decayed to 0.000500
# Epoch 188:
# Training loss: 0.1282, Training accuracy: 0.9811
# Validation loss: 0.8491, Validation accuracy: 0.7842
#
# Current learning rate has decayed to 0.000500
# Epoch 189:
# Training loss: 0.1319, Training accuracy: 0.9796
# Validation loss: 0.8495, Validation accuracy: 0.7856
#
# Current learning rate has decayed to 0.000500
# Epoch 190:
# Training loss: 0.1294, Training accuracy: 0.9808
# Validation loss: 0.8812, Validation accuracy: 0.7788
#
# Current learning rate has decayed to 0.000500
# Epoch 191:
# Training loss: 0.1308, Training accuracy: 0.9803
# Validation loss: 0.8393, Validation accuracy: 0.7868
#
# Current learning rate has decayed to 0.000500
# Epoch 192:
# Training loss: 0.1302, Training accuracy: 0.9792
# Validation loss: 0.8506, Validation accuracy: 0.7854
#
# Current learning rate has decayed to 0.000500
# Epoch 193:
# Training loss: 0.1328, Training accuracy: 0.9793
# Validation loss: 0.8526, Validation accuracy: 0.7826
#
# Current learning rate has decayed to 0.000500
# Epoch 194:
# Training loss: 0.1284, Training accuracy: 0.9801
# Validation loss: 0.8682, Validation accuracy: 0.7832
#
# Current learning rate has decayed to 0.000500
# Epoch 195:
# Training loss: 0.1296, Training accuracy: 0.9801
# Validation loss: 0.8299, Validation accuracy: 0.7892
#
# Current learning rate has decayed to 0.000500
# Epoch 196:
# Training loss: 0.1294, Training accuracy: 0.9805
# Validation loss: 0.8341, Validation accuracy: 0.7892
#
# Current learning rate has decayed to 0.000500
# Epoch 197:
# Training loss: 0.1282, Training accuracy: 0.9811
# Validation loss: 0.8406, Validation accuracy: 0.7878
#
# Current learning rate has decayed to 0.000500
# Epoch 198:
# Training loss: 0.1309, Training accuracy: 0.9799
# Validation loss: 0.8711, Validation accuracy: 0.7806
#
# Current learning rate has decayed to 0.000500
# Epoch 199:
# Training loss: 0.1296, Training accuracy: 0.9806
# Validation loss: 0.8462, Validation accuracy: 0.7846
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.7954

# %%
print('ideas are just pass it pen, not pen[curr_batch_size:] - also ')
# Out:
# ideas are just pass it pen, not pen[curr_batch_size:] - also
