# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys 
sys.path.append('/content/drive/MyDrive/ECE_661/661_Final_Project')

# %%
# import necessary dependencies
import argparse
import os
import time
import tools
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import numpy as np

# %%
# define the ResBlock to be used in ResNet;
class ResBlock(nn.Module):
    def __init__(self, input_dim, output_dim, k_size=3, stride_bool=False):
        super(ResBlock, self).__init__()
        if(stride_bool == True):
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, stride=2, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1, stride=2)
        else:
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1)

        if input_dim != output_dim:
          input_dim = output_dim
        self.bn1 = nn.BatchNorm2d(output_dim)
        self.conv2 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
        self.bn2 = nn.BatchNorm2d(output_dim)

    def forward(self, x):
        y = x
      # Note shortcut will just be x if of same shape as out
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out)) 
        if (x.shape == out.shape):
          out = out + y
          out = F.relu(out)
          return out
        else:
          y = self.resconv(y)
          out = out.add(y)
          out = F.relu(out)
          return out

# %%
class ResNet(nn.Module):
  def __init__(self):
    super(ResNet, self).__init__()
    self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
    self.bn1 = nn.BatchNorm2d(16)
    # 16 filter res blockss
    self.res1 = ResBlock(16, 16)
    self.res2 = ResBlock(16, 16)
    self.res3 = ResBlock(16, 16)
    # Now 32 filter res blocks
    self.res4 = ResBlock(16, 32, stride_bool=True)
    self.res5 = ResBlock(32, 32)
    self.res6 = ResBlock(32, 32)
    # Now 64 filter res blocks 
    self.res7 = ResBlock(32, 64, stride_bool=True)
    self.res8 = ResBlock(64, 64)
    self.res9 = ResBlock(64, 64)

    self.fc = nn.Linear(64, 10)
    self.fc2 = nn.Linear(64,4)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))

    # ReLU contained within forward method of res blocks
    
    out = self.res1(out)
    out = self.res2(out)
    out = self.res3(out)

    out = self.res4(out)
    out = self.res5(out)
    out = self.res6(out)

    out = self.res7(out)
    out = self.res8(out)
    out = self.res9(out)

    out = F.adaptive_avg_pool2d(out, 1)
    out = out.view(out.size(0), -1)
    outt = self.fc(out)
    outr = self.fc2(out)
    # out = F.softmax(out)
    return outt, outr

# %%
class Cutout(object):
    """Randomly mask out one or more patches from an image.
    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010)),
                                      transforms.RandomCrop(size=(32,32), padding=4),
                                      transforms.RandomHorizontalFlip(), 
                                      transforms.RandomRotation(degrees=15),
                                      Cutout(n_holes=1, length=8)]) 
                                      # transforms.GaussianBlur(kernel_size=5, sigma = 0.5)])

transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))])
#############################################

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
# do NOT change these
#import tools
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 256
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train    # your code
)
val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val    # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size=256,  # your code
    shuffle=True,     # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set, 
    batch_size=256,  # your code
    shuffle=False,     # your code
    num_workers=4
)
#############################################
# Out:
# Downloading https://www.dropbox.com/s/s8orza214q45b23/cifar10_trainval_F22.zip?dl=1 to ./data/cifar10_trainval_F22.zip
# 0it [00:00, ?it/s]
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here
# GPU check                
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")
  
    
#############################################
# Out:
# Run on GPU...

# %%
# !nvidia-smi
# Out:
# Wed Dec 14 17:32:36 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    51W / 400W |      3MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

net = ResNet().to(device)
state_dict = torch.load("/content/drive/MyDrive/ECE_661/661_Final_Project/resnet_base_75.pth")
net.load_state_dict(state_dict["state_dict"])
# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-5

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss().to(device)

# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay = REG) #momentum value from AlexNet
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities?)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %% [markdown]
# ## Only data augmentation

# %%
# Code borrowed from Facebook research paper: https://github.com/facebookresearch/mixup-cifar10/blob/main/train.py
def mixup_data(x, y, alpha=1.0, use_cuda=True, lam = .5):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = lam
    

    batch_size = x.size()[0]
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
# Just data augmentation

# some hyperparameters
# total number of training epochs
EPOCHS = 100
 
# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

# Calculate initial loss 
initial_loss = 0
for batch_idx, (inputs, targets) in enumerate(train_loader):
  inputs = inputs.to(device)
  targets = targets.to(device)
  # compute the output and loss
  outputs = net(inputs)[0]
  initial_loss = criterion(outputs, targets)
  # initial_loss += loss
print("Initial loss: %.4f" %(initial_loss))

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
#     # handle the learning rate scheduler.
  #  if i % DECAY_EPOCHS == 0 and i != 0:
#         current_learning_rate = current_learning_rate * DECAY
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = current_learning_rate
#         print("Current learning rate has decayed to %f" %current_learning_rate)
    if 140 > i > 100  :
      current_learning_rate = 0.1
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
      print("Current learning rate has decayed to %f" %current_learning_rate)
    if 170 > i > 140  :
      current_learning_rate = 0.001
      momentum = 0.6
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
          param_group['momentum'] = momentum
      print("Current learning rate has decayed to %f" %current_learning_rate)
    if i > 170  :
      current_learning_rate = 0.0005
      momentum = 0.3
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
          param_group['momentum'] = momentum
      print("Current learning rate has decayed to %f" %current_learning_rate)
    
    
    #######################
    # your code here
    # switch to train mode
    net.train()
    #######################

    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # compute the output and loss
        # Alpha is a hyperparam that will influence our lambda valie
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets,
                                                       alpha=0.5, use_cuda=True)
        inputs, targets_a, targets_b = map(Variable, (inputs,
                                                      targets_a, targets_b))
        outputs = net(inputs)[0]
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)
        train_loss += loss
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        _, predicted = torch.max(outputs, 1)
        correct = predicted.eq(targets).sum()

        total_examples += targets.shape[0]
        correct_examples += correct.item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # compute the output and loss
            outputs = net(inputs)[0]
            val_loss += criterion(outputs, targets)
                
            # count the number of correctly predicted samples in the current batch
            _, predicted = torch.max(outputs, 1)
            correct = predicted.eq(targets).sum()

            total_examples += targets.shape[0]
            correct_examples += correct.item()
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_FOLDER):
           os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': net.state_dict(),
                'epoch': i,
                'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'resnet_mixup_cutout_174epoch.pth'))
        # model.load_state_dict(state_dict["state_dict"])
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# Initial loss: 0.3794
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.2199, Training accuracy: 0.4456
# Validation loss: 0.4803, Validation accuracy: 0.8606
# Saving ...
#
# Epoch 1:
# Training loss: 1.0946, Training accuracy: 0.5008
# Validation loss: 0.4564, Validation accuracy: 0.8542
#
# Epoch 2:
# Training loss: 1.0525, Training accuracy: 0.4688
# Validation loss: 0.4448, Validation accuracy: 0.8550
#
# Epoch 3:
# Training loss: 1.1053, Training accuracy: 0.4476
# Validation loss: 0.4289, Validation accuracy: 0.8670
# Saving ...
#
# Epoch 4:
# Training loss: 1.0413, Training accuracy: 0.5106
# Validation loss: 0.3760, Validation accuracy: 0.8806
# Saving ...
#
# Epoch 5:
# Training loss: 1.0174, Training accuracy: 0.4554
# Validation loss: 0.3952, Validation accuracy: 0.8740
#
# Epoch 6:
# Training loss: 1.0111, Training accuracy: 0.4381
# Validation loss: 0.4435, Validation accuracy: 0.8762
#
# Epoch 7:
# Training loss: 1.0278, Training accuracy: 0.5092
# Validation loss: 0.4578, Validation accuracy: 0.8738
#
# Epoch 8:
# Training loss: 0.9847, Training accuracy: 0.4659
# Validation loss: 0.4288, Validation accuracy: 0.8792
#
# Epoch 9:
# Training loss: 1.0009, Training accuracy: 0.4758
# Validation loss: 0.3985, Validation accuracy: 0.8710
#
# Epoch 10:
# Training loss: 0.9692, Training accuracy: 0.4744
# Validation loss: 0.4780, Validation accuracy: 0.8804
#
# Epoch 11:
# Training loss: 1.0461, Training accuracy: 0.4882
# Validation loss: 0.4652, Validation accuracy: 0.8584
#
# Epoch 12:
# Training loss: 1.0115, Training accuracy: 0.4481
# Validation loss: 0.3815, Validation accuracy: 0.8932
# Saving ...
#
# Epoch 13:
# Training loss: 1.0963, Training accuracy: 0.4757
# Validation loss: 0.4700, Validation accuracy: 0.8722
#
# Epoch 14:
# Training loss: 0.9446, Training accuracy: 0.4846
# Validation loss: 0.4402, Validation accuracy: 0.8648
#
# Epoch 15:
# Training loss: 0.9936, Training accuracy: 0.4830
# Validation loss: 0.4233, Validation accuracy: 0.8730
#
# Epoch 16:
# Training loss: 1.0026, Training accuracy: 0.4659
# Validation loss: 0.4155, Validation accuracy: 0.8784
#
# Epoch 17:
# Training loss: 0.9939, Training accuracy: 0.4801
# Validation loss: 0.4172, Validation accuracy: 0.8738
#
# Epoch 18:
# Training loss: 0.9882, Training accuracy: 0.4403
# Validation loss: 0.4706, Validation accuracy: 0.8686
#
# Epoch 19:
# Training loss: 0.9684, Training accuracy: 0.4285
# Validation loss: 0.4128, Validation accuracy: 0.8836
#
# Epoch 20:
# Training loss: 1.0534, Training accuracy: 0.4908
# Validation loss: 0.4789, Validation accuracy: 0.8816
#
# Epoch 21:
# Training loss: 0.9978, Training accuracy: 0.4977
# Validation loss: 0.4561, Validation accuracy: 0.8694
#
# Epoch 22:
# Training loss: 0.9683, Training accuracy: 0.4577
# Validation loss: 0.5138, Validation accuracy: 0.8700
#
# Epoch 23:
# Training loss: 0.9779, Training accuracy: 0.4927
# Validation loss: 0.4021, Validation accuracy: 0.8848
#
# Epoch 24:
# Training loss: 0.9851, Training accuracy: 0.4528
# Validation loss: 0.4305, Validation accuracy: 0.8840
#
# Epoch 25:
# Training loss: 0.8954, Training accuracy: 0.4630
# Validation loss: 0.4084, Validation accuracy: 0.8828
#
# Epoch 26:
# Training loss: 0.9391, Training accuracy: 0.4640
# Validation loss: 0.4459, Validation accuracy: 0.8754
#
# Epoch 27:
# Training loss: 0.9665, Training accuracy: 0.4676
# Validation loss: 0.4231, Validation accuracy: 0.8714
#
# Epoch 28:
# Training loss: 0.9718, Training accuracy: 0.5549
# Validation loss: 0.5034, Validation accuracy: 0.8742
#
# Epoch 29:
# Training loss: 0.9242, Training accuracy: 0.4570
# Validation loss: 0.3927, Validation accuracy: 0.8856
#
# Epoch 30:
# Training loss: 0.9761, Training accuracy: 0.4848
# Validation loss: 0.4223, Validation accuracy: 0.8800
#
# Epoch 31:
# Training loss: 0.8973, Training accuracy: 0.4620
# Validation loss: 0.4120, Validation accuracy: 0.8822
#
# Epoch 32:
# Training loss: 1.0030, Training accuracy: 0.5287
# Validation loss: 0.4227, Validation accuracy: 0.8772
#
# Epoch 33:
# Training loss: 0.8788, Training accuracy: 0.5411
# Validation loss: 0.4311, Validation accuracy: 0.8680
#
# Epoch 34:
# Training loss: 1.0130, Training accuracy: 0.4850
# Validation loss: 0.4671, Validation accuracy: 0.8738
#
# Epoch 35:
# Training loss: 0.9781, Training accuracy: 0.4927
# Validation loss: 0.4046, Validation accuracy: 0.8806
#
# Epoch 36:
# Training loss: 0.9888, Training accuracy: 0.5105
# Validation loss: 0.3823, Validation accuracy: 0.8830
#
# Epoch 37:
# Training loss: 1.0148, Training accuracy: 0.4891
# Validation loss: 0.4960, Validation accuracy: 0.8650
#
# Epoch 38:
# Training loss: 0.9248, Training accuracy: 0.5120
# Validation loss: 0.3889, Validation accuracy: 0.8790
#
# Epoch 39:
# Training loss: 0.9194, Training accuracy: 0.4837
# Validation loss: 0.4115, Validation accuracy: 0.8834
#
# Epoch 40:
# Training loss: 0.9294, Training accuracy: 0.4896
# Validation loss: 0.4493, Validation accuracy: 0.8734
#
# Epoch 41:
# Training loss: 0.9843, Training accuracy: 0.4636
# Validation loss: 0.4281, Validation accuracy: 0.8838
#
# Epoch 42:
# Training loss: 0.9680, Training accuracy: 0.4852
# Validation loss: 0.4309, Validation accuracy: 0.8808
#
# Epoch 43:
# Training loss: 0.9918, Training accuracy: 0.4460
# Validation loss: 0.4090, Validation accuracy: 0.8906
#
# Epoch 44:
# Training loss: 0.9646, Training accuracy: 0.5179
# Validation loss: 0.3877, Validation accuracy: 0.8882
#
# Epoch 45:
# Training loss: 0.9172, Training accuracy: 0.4848
# Validation loss: 0.3876, Validation accuracy: 0.8864
#
# Epoch 46:
# Training loss: 0.9907, Training accuracy: 0.4838
# Validation loss: 0.4411, Validation accuracy: 0.8770
#
# Epoch 47:
# Training loss: 0.9643, Training accuracy: 0.5039
# Validation loss: 0.4615, Validation accuracy: 0.8696
#
# Epoch 48:
# Training loss: 0.8997, Training accuracy: 0.4750
# Validation loss: 0.4384, Validation accuracy: 0.8774
#
# Epoch 49:
# Training loss: 0.9387, Training accuracy: 0.4813
# Validation loss: 0.4344, Validation accuracy: 0.8782
#
# Epoch 50:
# Training loss: 0.9940, Training accuracy: 0.4566
# Validation loss: 0.4418, Validation accuracy: 0.8848
#
# Epoch 51:
# Training loss: 1.0305, Training accuracy: 0.4897
# Validation loss: 0.4526, Validation accuracy: 0.8766
#
# Epoch 52:
# Training loss: 1.0468, Training accuracy: 0.4534
# Validation loss: 0.4826, Validation accuracy: 0.8734
#
# Epoch 53:
# Training loss: 0.9497, Training accuracy: 0.5011
# Validation loss: 0.4053, Validation accuracy: 0.8786
#
# Epoch 54:
# Training loss: 0.9862, Training accuracy: 0.4842
# Validation loss: 0.4417, Validation accuracy: 0.8732
#
# Epoch 55:
# Training loss: 0.9318, Training accuracy: 0.5124
# Validation loss: 0.4342, Validation accuracy: 0.8790
#
# Epoch 56:
# Training loss: 0.9267, Training accuracy: 0.4560
# Validation loss: 0.4716, Validation accuracy: 0.8738
#
# Epoch 57:
# Training loss: 0.9232, Training accuracy: 0.5025
# Validation loss: 0.4034, Validation accuracy: 0.8850
#
# Epoch 58:
# Training loss: 0.8801, Training accuracy: 0.4904
# Validation loss: 0.4332, Validation accuracy: 0.8802
#
# Epoch 59:
# Training loss: 0.9733, Training accuracy: 0.4775
# Validation loss: 0.4304, Validation accuracy: 0.8802
#
# Epoch 60:
# Training loss: 0.9508, Training accuracy: 0.4927
# Validation loss: 0.3766, Validation accuracy: 0.8928
#
# Epoch 61:
# Training loss: 1.0211, Training accuracy: 0.4639
# Validation loss: 0.4310, Validation accuracy: 0.8954
# Saving ...
#
# Epoch 62:
# Training loss: 0.9574, Training accuracy: 0.5021
# Validation loss: 0.4442, Validation accuracy: 0.8852
#
# Epoch 63:
# Training loss: 0.9689, Training accuracy: 0.4815
# Validation loss: 0.4370, Validation accuracy: 0.8808
#
# Epoch 64:
# Training loss: 1.0272, Training accuracy: 0.4621
# Validation loss: 0.4350, Validation accuracy: 0.8870
#
# Epoch 65:
# Training loss: 0.9274, Training accuracy: 0.4568
# Validation loss: 0.5061, Validation accuracy: 0.8664
#
# Epoch 66:
# Training loss: 0.9274, Training accuracy: 0.5131
# Validation loss: 0.4202, Validation accuracy: 0.8880
#
# Epoch 67:
# Training loss: 0.8987, Training accuracy: 0.4380
# Validation loss: 0.4259, Validation accuracy: 0.8768
#
# Epoch 68:
# Training loss: 0.9890, Training accuracy: 0.4750
# Validation loss: 0.4449, Validation accuracy: 0.8858
#
# Epoch 69:
# Training loss: 0.9739, Training accuracy: 0.4831
# Validation loss: 0.4274, Validation accuracy: 0.8844
#
# Epoch 70:
# Training loss: 0.9053, Training accuracy: 0.4810
# Validation loss: 0.5398, Validation accuracy: 0.8488
#
# Epoch 71:
# Training loss: 0.8996, Training accuracy: 0.5263
# Validation loss: 0.3965, Validation accuracy: 0.8844
#
# Epoch 72:
# Training loss: 0.9330, Training accuracy: 0.4892
# Validation loss: 0.3677, Validation accuracy: 0.8906
#
# Epoch 73:
# Training loss: 0.9769, Training accuracy: 0.4600
# Validation loss: 0.3956, Validation accuracy: 0.8812
#
# Epoch 74:
# Training loss: 0.9649, Training accuracy: 0.4515
# Validation loss: 0.4175, Validation accuracy: 0.8858
#
# Epoch 75:
# Training loss: 0.8936, Training accuracy: 0.4782
# Validation loss: 0.3962, Validation accuracy: 0.8874
#
# Epoch 76:
# Training loss: 0.9406, Training accuracy: 0.4618
# Validation loss: 0.4148, Validation accuracy: 0.8884
#
# Epoch 77:
# Training loss: 0.9236, Training accuracy: 0.5057
# Validation loss: 0.4136, Validation accuracy: 0.8912
#
# Epoch 78:
# Training loss: 1.0233, Training accuracy: 0.4660
# Validation loss: 0.4464, Validation accuracy: 0.8730
#
# Epoch 79:
# Training loss: 0.9404, Training accuracy: 0.5177
# Validation loss: 0.4241, Validation accuracy: 0.8784
#
# Epoch 80:
# Training loss: 0.9264, Training accuracy: 0.4972
# Validation loss: 0.3906, Validation accuracy: 0.8942
#
# Epoch 81:
# Training loss: 0.9448, Training accuracy: 0.4869
# Validation loss: 0.4949, Validation accuracy: 0.8656
#
# Epoch 82:
# Training loss: 0.9555, Training accuracy: 0.5410
# Validation loss: 0.3755, Validation accuracy: 0.8934
#
# Epoch 83:
# Training loss: 0.9482, Training accuracy: 0.4938
# Validation loss: 0.4146, Validation accuracy: 0.8750
#
# Epoch 84:
# Training loss: 0.9427, Training accuracy: 0.4605
# Validation loss: 0.3695, Validation accuracy: 0.8972
# Saving ...
#
# Epoch 85:
# Training loss: 0.9164, Training accuracy: 0.4724
# Validation loss: 0.4234, Validation accuracy: 0.8794
#
# Epoch 86:
# Training loss: 0.9849, Training accuracy: 0.4764
# Validation loss: 0.5218, Validation accuracy: 0.8608
#
# Epoch 87:
# Training loss: 0.9620, Training accuracy: 0.4464
# Validation loss: 0.4209, Validation accuracy: 0.8896
#
# Epoch 88:
# Training loss: 0.9592, Training accuracy: 0.4614
# Validation loss: 0.4467, Validation accuracy: 0.8798
#
# Epoch 89:
# Training loss: 0.9565, Training accuracy: 0.5170
# Validation loss: 0.4055, Validation accuracy: 0.8728
#
# Epoch 90:
# Training loss: 0.9224, Training accuracy: 0.4668
# Validation loss: 0.4142, Validation accuracy: 0.8884
#
# Epoch 91:
# Training loss: 0.8998, Training accuracy: 0.4761
# Validation loss: 0.3704, Validation accuracy: 0.8958
#
# Epoch 92:
# Training loss: 1.0403, Training accuracy: 0.4863
# Validation loss: 0.4758, Validation accuracy: 0.8860
#
# Epoch 93:
# Training loss: 0.8946, Training accuracy: 0.4266
# Validation loss: 0.3978, Validation accuracy: 0.8902
#
# Epoch 94:
# Training loss: 0.8955, Training accuracy: 0.4412
# Validation loss: 0.3775, Validation accuracy: 0.8896
#
# Epoch 95:
# Training loss: 0.9268, Training accuracy: 0.5166
# Validation loss: 0.4011, Validation accuracy: 0.8950
#
# Epoch 96:
# Training loss: 0.9350, Training accuracy: 0.5039
# Validation loss: 0.3936, Validation accuracy: 0.8914
#
# Epoch 97:
# Training loss: 0.9485, Training accuracy: 0.4433
# Validation loss: 0.5024, Validation accuracy: 0.8648
#
# Epoch 98:
# Training loss: 0.8589, Training accuracy: 0.5084
# Validation loss: 0.4225, Validation accuracy: 0.8802
#
# Epoch 99:
# Training loss: 0.9543, Training accuracy: 0.4972
# Validation loss: 0.3942, Validation accuracy: 0.8796
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8972
