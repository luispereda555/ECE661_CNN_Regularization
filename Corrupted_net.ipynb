# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys 
sys.path.append('/content/drive/MyDrive/ECE_661/661_Final_Project')

# %%
# import necessary dependencies
import argparse
import os
import time
import tools
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np

# %%
# define the ResBlock to be used in ResNet;
class ResBlock(nn.Module):
    def __init__(self, input_dim, output_dim, k_size=3, stride_bool=False):
        super(ResBlock, self).__init__()
        if(stride_bool == True):
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, stride=2, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1, stride=2)
        else:
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1)

        if input_dim != output_dim:
          input_dim = output_dim
        self.bn1 = nn.BatchNorm2d(output_dim)
        self.conv2 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
        self.bn2 = nn.BatchNorm2d(output_dim)

    def forward(self, x):
        y = x
      # Note shortcut will just be x if of same shape as out
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out)) 
        if (x.shape == out.shape):
          out = out + y
          out = F.relu(out)
          return out
        else:
          y = self.resconv(y)
          out = out.add(y)
          out = F.relu(out)
          return out

# %%
class ResNet(nn.Module):
  def __init__(self):
    super(ResNet, self).__init__()
    self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
    self.bn1 = nn.BatchNorm2d(16)
    # 16 filter res blockss
    self.res1 = ResBlock(16, 16)
    self.res2 = ResBlock(16, 16)
    self.res3 = ResBlock(16, 16)
    # Now 32 filter res blocks
    self.res4 = ResBlock(16, 32, stride_bool=True)
    self.res5 = ResBlock(32, 32)
    self.res6 = ResBlock(32, 32)
    # Now 64 filter res blocks 
    self.res7 = ResBlock(32, 64, stride_bool=True)
    self.res8 = ResBlock(64, 64)
    self.res9 = ResBlock(64, 64)

    self.fc = nn.Linear(64, 10)
    self.fc2 = nn.Linear(64,4)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))

    # ReLU contained within forward method of res blocks
    
    out = self.res1(out)
    out = self.res2(out)
    out = self.res3(out)

    out = self.res4(out)
    out = self.res5(out)
    out = self.res6(out)

    out = self.res7(out)
    out = self.res8(out)
    out = self.res9(out)

    out = F.adaptive_avg_pool2d(out, 1)
    out = out.view(out.size(0), -1)
    outt = self.fc(out)
    outr = self.fc2(out)
    # out = F.softmax(out)
    return outt, outr

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010)),
                                      transforms.RandomCrop(size=(32,32), padding=4),
                                      transforms.RandomHorizontalFlip(), 
                                      transforms.RandomRotation(degrees=15)]) 
                                      # transforms.GaussianBlur(kernel_size=5, sigma = 0.5)])

transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))])
#############################################

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
# do NOT change these
#import tools
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 256
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train    # your code
)
val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val    # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size=256,  # your code
    shuffle=True,     # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set, 
    batch_size=256,  # your code
    shuffle=False,     # your code
    num_workers=4
)
#############################################
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here
# GPU check                
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")
  
    
#############################################
# Out:
# Run on GPU...

# %%
# !nvidia-smi
# Out:
# Wed Dec 14 06:54:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    49W / 400W |      3MiB / 40536MiB |     25%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

net = ResNet().to(device)
# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-5

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss().to(device)

# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay = REG) #momentum value from AlexNet
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities?)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %% [markdown]
# ## Only data augmentation

# %%
# Just data augmentation

# some hyperparameters
# total number of training epochs
EPOCHS = 75
 
# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

# Calculate initial loss 
initial_loss = 0
for batch_idx, (inputs, targets) in enumerate(train_loader):
  inputs = inputs.to(device)
  targets = targets.to(device)
  # compute the output and loss
  outputs = net(inputs)[0]
  initial_loss = criterion(outputs, targets)
  # initial_loss += loss
print("Initial loss: %.4f" %(initial_loss))

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
#     # handle the learning rate scheduler.
  #  if i % DECAY_EPOCHS == 0 and i != 0:
#         current_learning_rate = current_learning_rate * DECAY
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = current_learning_rate
#         print("Current learning rate has decayed to %f" %current_learning_rate)
    if 140 > i > 100  :
      current_learning_rate = 0.1
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
      print("Current learning rate has decayed to %f" %current_learning_rate)
    if 170 > i > 140  :
      current_learning_rate = 0.001
      momentum = 0.6
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
          param_group['momentum'] = momentum
      print("Current learning rate has decayed to %f" %current_learning_rate)
    if i > 170  :
      current_learning_rate = 0.0005
      momentum = 0.3
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
          param_group['momentum'] = momentum
      print("Current learning rate has decayed to %f" %current_learning_rate)
    
    
    #######################
    # your code here
    # switch to train mode
    net.train()
    #######################

    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # compute the output and loss
        outputs = net(inputs)[0]
        loss = criterion(outputs, targets)
        train_loss += loss
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        _, predicted = torch.max(outputs, 1)
        correct = predicted.eq(targets).sum()

        total_examples += targets.shape[0]
        correct_examples += correct.item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # compute the output and loss
            outputs = net(inputs)[0]
            val_loss += criterion(outputs, targets)
            
            # count the number of correctly predicted samples in the current batch
            _, predicted = torch.max(outputs, 1)
            correct = predicted.eq(targets).sum()

            total_examples += targets.shape[0]
            correct_examples += correct.item()
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_FOLDER):
           os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': net.state_dict(),
                'epoch': i,
                'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'resnet_base_75.pth'))
        # model.load_state_dict(state_dict["state_dict"])
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# Initial loss: 2.4278
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.7643, Training accuracy: 0.3340
# Validation loss: 1.5657, Validation accuracy: 0.4136
# Saving ...
#
# Epoch 1:
# Training loss: 1.3753, Training accuracy: 0.4977
# Validation loss: 1.5143, Validation accuracy: 0.4566
# Saving ...
#
# Epoch 2:
# Training loss: 1.1636, Training accuracy: 0.5801
# Validation loss: 1.3096, Validation accuracy: 0.5416
# Saving ...
#
# Epoch 3:
# Training loss: 1.0130, Training accuracy: 0.6414
# Validation loss: 0.9911, Validation accuracy: 0.6560
# Saving ...
#
# Epoch 4:
# Training loss: 0.9071, Training accuracy: 0.6774
# Validation loss: 0.9231, Validation accuracy: 0.6892
# Saving ...
#
# Epoch 5:
# Training loss: 0.8212, Training accuracy: 0.7103
# Validation loss: 0.9647, Validation accuracy: 0.6680
#
# Epoch 6:
# Training loss: 0.7663, Training accuracy: 0.7308
# Validation loss: 0.7918, Validation accuracy: 0.7308
# Saving ...
#
# Epoch 7:
# Training loss: 0.7139, Training accuracy: 0.7493
# Validation loss: 0.7549, Validation accuracy: 0.7442
# Saving ...
#
# Epoch 8:
# Training loss: 0.6798, Training accuracy: 0.7618
# Validation loss: 0.7177, Validation accuracy: 0.7574
# Saving ...
#
# Epoch 9:
# Training loss: 0.6488, Training accuracy: 0.7740
# Validation loss: 0.7270, Validation accuracy: 0.7542
#
# Epoch 10:
# Training loss: 0.6269, Training accuracy: 0.7821
# Validation loss: 0.5981, Validation accuracy: 0.7988
# Saving ...
#
# Epoch 11:
# Training loss: 0.5989, Training accuracy: 0.7894
# Validation loss: 0.6390, Validation accuracy: 0.7804
#
# Epoch 12:
# Training loss: 0.5750, Training accuracy: 0.7994
# Validation loss: 0.6054, Validation accuracy: 0.7942
#
# Epoch 13:
# Training loss: 0.5548, Training accuracy: 0.8067
# Validation loss: 0.6255, Validation accuracy: 0.7866
#
# Epoch 14:
# Training loss: 0.5414, Training accuracy: 0.8107
# Validation loss: 0.7650, Validation accuracy: 0.7600
#
# Epoch 15:
# Training loss: 0.5243, Training accuracy: 0.8163
# Validation loss: 0.5808, Validation accuracy: 0.8066
# Saving ...
#
# Epoch 16:
# Training loss: 0.5138, Training accuracy: 0.8202
# Validation loss: 0.5294, Validation accuracy: 0.8212
# Saving ...
#
# Epoch 17:
# Training loss: 0.4951, Training accuracy: 0.8279
# Validation loss: 0.7708, Validation accuracy: 0.7608
#
# Epoch 18:
# Training loss: 0.4814, Training accuracy: 0.8328
# Validation loss: 0.5023, Validation accuracy: 0.8320
# Saving ...
#
# Epoch 19:
# Training loss: 0.4700, Training accuracy: 0.8357
# Validation loss: 0.5219, Validation accuracy: 0.8230
#
# Epoch 20:
# Training loss: 0.4646, Training accuracy: 0.8393
# Validation loss: 0.5507, Validation accuracy: 0.8220
#
# Epoch 21:
# Training loss: 0.4548, Training accuracy: 0.8395
# Validation loss: 0.5991, Validation accuracy: 0.8038
#
# Epoch 22:
# Training loss: 0.4451, Training accuracy: 0.8448
# Validation loss: 0.5550, Validation accuracy: 0.8152
#
# Epoch 23:
# Training loss: 0.4337, Training accuracy: 0.8480
# Validation loss: 0.5385, Validation accuracy: 0.8220
#
# Epoch 24:
# Training loss: 0.4231, Training accuracy: 0.8522
# Validation loss: 0.5755, Validation accuracy: 0.8200
#
# Epoch 25:
# Training loss: 0.4123, Training accuracy: 0.8538
# Validation loss: 0.5581, Validation accuracy: 0.8212
#
# Epoch 26:
# Training loss: 0.4138, Training accuracy: 0.8565
# Validation loss: 0.5411, Validation accuracy: 0.8294
#
# Epoch 27:
# Training loss: 0.3951, Training accuracy: 0.8617
# Validation loss: 0.5091, Validation accuracy: 0.8360
# Saving ...
#
# Epoch 28:
# Training loss: 0.3948, Training accuracy: 0.8619
# Validation loss: 0.4824, Validation accuracy: 0.8382
# Saving ...
#
# Epoch 29:
# Training loss: 0.3873, Training accuracy: 0.8638
# Validation loss: 0.4441, Validation accuracy: 0.8580
# Saving ...
#
# Epoch 30:
# Training loss: 0.3770, Training accuracy: 0.8680
# Validation loss: 0.5599, Validation accuracy: 0.8310
#
# Epoch 31:
# Training loss: 0.3773, Training accuracy: 0.8679
# Validation loss: 0.4391, Validation accuracy: 0.8520
#
# Epoch 32:
# Training loss: 0.3670, Training accuracy: 0.8702
# Validation loss: 0.4483, Validation accuracy: 0.8506
#
# Epoch 33:
# Training loss: 0.3634, Training accuracy: 0.8699
# Validation loss: 0.5673, Validation accuracy: 0.8288
#
# Epoch 34:
# Training loss: 0.3623, Training accuracy: 0.8741
# Validation loss: 0.5102, Validation accuracy: 0.8330
#
# Epoch 35:
# Training loss: 0.3595, Training accuracy: 0.8732
# Validation loss: 0.4965, Validation accuracy: 0.8394
#
# Epoch 36:
# Training loss: 0.3518, Training accuracy: 0.8757
# Validation loss: 0.4285, Validation accuracy: 0.8568
#
# Epoch 37:
# Training loss: 0.3442, Training accuracy: 0.8783
# Validation loss: 0.4427, Validation accuracy: 0.8556
#
# Epoch 38:
# Training loss: 0.3377, Training accuracy: 0.8809
# Validation loss: 0.5941, Validation accuracy: 0.8114
#
# Epoch 39:
# Training loss: 0.3357, Training accuracy: 0.8821
# Validation loss: 0.4014, Validation accuracy: 0.8650
# Saving ...
#
# Epoch 40:
# Training loss: 0.3342, Training accuracy: 0.8817
# Validation loss: 0.4843, Validation accuracy: 0.8492
#
# Epoch 41:
# Training loss: 0.3273, Training accuracy: 0.8850
# Validation loss: 0.4344, Validation accuracy: 0.8614
#
# Epoch 42:
# Training loss: 0.3265, Training accuracy: 0.8849
# Validation loss: 0.4140, Validation accuracy: 0.8652
# Saving ...
#
# Epoch 43:
# Training loss: 0.3136, Training accuracy: 0.8898
# Validation loss: 0.4535, Validation accuracy: 0.8606
#
# Epoch 44:
# Training loss: 0.3149, Training accuracy: 0.8891
# Validation loss: 0.4217, Validation accuracy: 0.8626
#
# Epoch 45:
# Training loss: 0.3128, Training accuracy: 0.8891
# Validation loss: 0.4513, Validation accuracy: 0.8594
#
# Epoch 46:
# Training loss: 0.3102, Training accuracy: 0.8910
# Validation loss: 0.4201, Validation accuracy: 0.8634
#
# Epoch 47:
# Training loss: 0.3061, Training accuracy: 0.8923
# Validation loss: 0.4272, Validation accuracy: 0.8660
# Saving ...
#
# Epoch 48:
# Training loss: 0.2954, Training accuracy: 0.8958
# Validation loss: 0.4318, Validation accuracy: 0.8586
#
# Epoch 49:
# Training loss: 0.2996, Training accuracy: 0.8944
# Validation loss: 0.4216, Validation accuracy: 0.8746
# Saving ...
#
# Epoch 50:
# Training loss: 0.2941, Training accuracy: 0.8959
# Validation loss: 0.4740, Validation accuracy: 0.8572
#
# Epoch 51:
# Training loss: 0.2883, Training accuracy: 0.8975
# Validation loss: 0.4543, Validation accuracy: 0.8600
#
# Epoch 52:
# Training loss: 0.2909, Training accuracy: 0.8971
# Validation loss: 0.4140, Validation accuracy: 0.8660
#
# Epoch 53:
# Training loss: 0.2816, Training accuracy: 0.8999
# Validation loss: 0.4256, Validation accuracy: 0.8656
#
# Epoch 54:
# Training loss: 0.2837, Training accuracy: 0.8996
# Validation loss: 0.4073, Validation accuracy: 0.8718
#
# Epoch 55:
# Training loss: 0.2792, Training accuracy: 0.9029
# Validation loss: 0.4586, Validation accuracy: 0.8620
#
# Epoch 56:
# Training loss: 0.2753, Training accuracy: 0.9018
# Validation loss: 0.4361, Validation accuracy: 0.8668
#
# Epoch 57:
# Training loss: 0.2742, Training accuracy: 0.9008
# Validation loss: 0.4236, Validation accuracy: 0.8668
#
# Epoch 58:
# Training loss: 0.2729, Training accuracy: 0.9038
# Validation loss: 0.4322, Validation accuracy: 0.8660
#
# Epoch 59:
# Training loss: 0.2698, Training accuracy: 0.9053
# Validation loss: 0.3808, Validation accuracy: 0.8814
# Saving ...
#
# Epoch 60:
# Training loss: 0.2655, Training accuracy: 0.9059
# Validation loss: 0.3828, Validation accuracy: 0.8792
#
# Epoch 61:
# Training loss: 0.2630, Training accuracy: 0.9070
# Validation loss: 0.4162, Validation accuracy: 0.8736
#
# Epoch 62:
# Training loss: 0.2639, Training accuracy: 0.9071
# Validation loss: 0.3581, Validation accuracy: 0.8872
# Saving ...
#
# Epoch 63:
# Training loss: 0.2523, Training accuracy: 0.9117
# Validation loss: 0.4644, Validation accuracy: 0.8650
#
# Epoch 64:
# Training loss: 0.2546, Training accuracy: 0.9084
# Validation loss: 0.4178, Validation accuracy: 0.8708
#
# Epoch 65:
# Training loss: 0.2570, Training accuracy: 0.9100
# Validation loss: 0.4845, Validation accuracy: 0.8598
#
# Epoch 66:
# Training loss: 0.2486, Training accuracy: 0.9113
# Validation loss: 0.3895, Validation accuracy: 0.8780
#
# Epoch 67:
# Training loss: 0.2493, Training accuracy: 0.9110
# Validation loss: 0.3922, Validation accuracy: 0.8796
#
# Epoch 68:
# Training loss: 0.2517, Training accuracy: 0.9098
# Validation loss: 0.3869, Validation accuracy: 0.8800
#
# Epoch 69:
# Training loss: 0.2472, Training accuracy: 0.9119
# Validation loss: 0.4181, Validation accuracy: 0.8732
#
# Epoch 70:
# Training loss: 0.2378, Training accuracy: 0.9144
# Validation loss: 0.4066, Validation accuracy: 0.8802
#
# Epoch 71:
# Training loss: 0.2477, Training accuracy: 0.9099
# Validation loss: 0.3869, Validation accuracy: 0.8766
#
# Epoch 72:
# Training loss: 0.2323, Training accuracy: 0.9175
# Validation loss: 0.4548, Validation accuracy: 0.8726
#
# Epoch 73:
# Training loss: 0.2378, Training accuracy: 0.9164
# Validation loss: 0.4492, Validation accuracy: 0.8676
#
# Epoch 74:
# Training loss: 0.2366, Training accuracy: 0.9145
# Validation loss: 0.4609, Validation accuracy: 0.8568
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8872
