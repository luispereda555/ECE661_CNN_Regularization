# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys 
sys.path.append('/content/drive/MyDrive/ECE_661/661_Final_Project')

# %%
# !ls
# Out:
# data  drive  sample_data  saved_model

# %%
# import necessary dependencies
import argparse
import os
import time
import tools
import datetime
from tqdm import tqdm_notebook as tqdm
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
from tools.dataset import CIFAR10
from torchvision.datasets import CIFAR10 as CIFAR
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
from typing import Any, Callable, Optional, Tuple

# %%
# define the ResBlock to be used in ResNet;
class ResBlock(nn.Module):
    def __init__(self, input_dim, output_dim, k_size=3, stride_bool=False):
        super(ResBlock, self).__init__()
        if(stride_bool == True):
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, stride=2, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1, stride=2)
        else:
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1)

        if input_dim != output_dim:
          input_dim = output_dim
        self.bn1 = nn.BatchNorm2d(output_dim)
        self.conv2 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
        self.bn2 = nn.BatchNorm2d(output_dim)

    def forward(self, x):
        y = x
      # Note shortcut will just be x if of same shape as out
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out)) 
        if (x.shape == out.shape):
          out = out + y
          out = F.relu(out)
          return out
        else:
          y = self.resconv(y)
          out = out.add(y)
          out = F.relu(out)
          return out

# %%
class ResNet(nn.Module):
  def __init__(self):
    super(ResNet, self).__init__()
    self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
    self.bn1 = nn.BatchNorm2d(16)
    # 16 filter res blockss
    self.res1 = ResBlock(16, 16)
    self.res2 = ResBlock(16, 16)
    self.res3 = ResBlock(16, 16)
    # Now 32 filter res blocks
    self.res4 = ResBlock(16, 32, stride_bool=True)
    self.res5 = ResBlock(32, 32)
    self.res6 = ResBlock(32, 32)
    # Now 64 filter res blocks 
    self.res7 = ResBlock(32, 64, stride_bool=True)
    self.res8 = ResBlock(64, 64)
    self.res9 = ResBlock(64, 64)

    self.fc = nn.Linear(64, 10)
    self.fc2 = nn.Linear(64,4)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))

    # ReLU contained within forward method of res blocks
    
    out = self.res1(out)
    out = self.res2(out)
    out = self.res3(out)

    out = self.res4(out)
    out = self.res5(out)
    out = self.res6(out)

    out = self.res7(out)
    out = self.res8(out)
    out = self.res9(out)

    out = F.adaptive_avg_pool2d(out, 1)
    out = out.view(out.size(0), -1)
    outt = self.fc(out)
    outr = self.fc2(out)
    # out = F.softmax(out)
    return outt, outr

# %%
class Cutout(object):
    """Randomly mask out one or more patches from an image.
    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img

# %%
def make_transform(n_holes, length):
  transform_train = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010)),
                                      Cutout(n_holes=n_holes, length=length)])
                                      # transforms.RandomHorizontalFlip(), 
                                      # transforms.RandomRotation(degrees=15)]) 
                                      # transforms.GaussianBlur(kernel_size=5, sigma = 0.5)])
  return transform_train


def make_train_set(transform_train):
  train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train    # your code
  )
  return train_set 


def make_train_loader(train_set):
  # construct dataloader
  train_loader = DataLoader(
    train_set, 
    batch_size=TRAIN_BATCH_SIZE,  # your code
    shuffle=True,     # your code
    num_workers=4
  )
  return train_loader


transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))])

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100


val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val    # your code
)

val_loader = DataLoader(
    val_set, 
    batch_size=256,  # your code
    shuffle=False,     # your code
    num_workers=4
)
#############################################
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here
# GPU check                
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")
  
    
#############################################
# Out:
# Run on GPU...

# %%
def fine_tune(train_loader, holes):
  print(f"Considering holes = {holes}") 
  net = ResNet().to(device)
  # state_dict = torch.load("/content/drive/MyDrive/ECE_661/661_Final_Project/resnet_base_noreg_50.pth")
  # net.load_state_dict(state_dict["state_dict"])

  INITIAL_LR = 0.1

  MOMENTUM = 0.9

  REG = 1e-5

  criterion = nn.CrossEntropyLoss().to(device)

  optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9, weight_decay = REG) #momentum value from AlexNet
  # some hyperparameters
  # total number of training epochs
  EPOCHS = 75
  
  # the folder where the trained model is saved
  CHECKPOINT_FOLDER = "./saved_model"

  # start the training/validation process
  # the process should take about 5 minutes on a GTX 1070-Ti
  # if the code is written efficiently.
  best_val_acc = 0
  current_learning_rate = INITIAL_LR

  # Calculate initial loss 
  initial_loss = 0
  for batch_idx, (inputs, targets) in enumerate(train_loader):
    inputs = inputs.to(device)
    targets = targets.to(device)
    # compute the output and loss
    outputs = net(inputs)[0]
    initial_loss = criterion(outputs, targets)
    # initial_loss += loss
  print("Initial loss: %.4f" %(initial_loss))

  print("==> Training starts!")
  print("="*50)
  for i in range(0, EPOCHS):
  
      #######################
      # your code here
      # switch to train mode
      net.train()
      #######################

      print("Epoch %d:" %i)
      # this help you compute the training accuracy
      total_examples = 0
      correct_examples = 0

      train_loss = 0 # track training loss if you want
      
      # Train the model for 1 epoch.
      for batch_idx, (inputs, targets) in enumerate(train_loader):
          ####################################
          # your code here
          # copy inputs to device
          inputs = inputs.to(device)
          targets = targets.to(device)
          # compute the output and loss
          outputs = net(inputs)[0]
          loss = criterion(outputs, targets)
          train_loss += loss
          # zero the gradient
          optimizer.zero_grad()
          
          # backpropagation
          loss.backward()
          
          # apply gradient and update the weights
          optimizer.step()
          
          # count the number of correctly predicted samples in the current batch
          _, predicted = torch.max(outputs, 1)
          correct = predicted.eq(targets).sum()

          total_examples += targets.shape[0]
          correct_examples += correct.item()
          ####################################
                  
      avg_loss = train_loss / len(train_loader)
      avg_acc = correct_examples / total_examples
      print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

      # Validate on the validation dataset
      #######################
      # your code here
      # switch to eval mode
      net.eval()
      
      #######################

      # this help you compute the validation accuracy
      total_examples = 0
      correct_examples = 0
      
      val_loss = 0 # again, track the validation loss if you want

      # disable gradient during validation, which can save GPU memory
      with torch.no_grad():
          for batch_idx, (inputs, targets) in enumerate(val_loader):
              ####################################
              # your code here
              # copy inputs to device
              inputs = inputs.to(device)
              targets = targets.to(device)
              # compute the output and loss
              outputs = net(inputs)[0]
              val_loss += criterion(outputs, targets)
              
              # count the number of correctly predicted samples in the current batch
              _, predicted = torch.max(outputs, 1)
              correct = predicted.eq(targets).sum()

              total_examples += targets.shape[0]
              correct_examples += correct.item()
              ####################################

      avg_loss = val_loss / len(val_loader)
      avg_acc = correct_examples / total_examples
      print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
      
      # save the model checkpoint
      if avg_acc > best_val_acc:
          best_val_acc = avg_acc
          if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
          print("Saving ...")
          state = {'state_dict': net.state_dict(),
                  'epoch': i,
                  'lr': current_learning_rate}
          torch.save(state, os.path.join(CHECKPOINT_FOLDER, f'resnet_cutout_only_finetune_{holes}.pth'))
          # model.load_state_dict(state_dict["state_dict"])
      print('')

  print("="*50)
  print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")

# %% [markdown]
# ## Sweep cutout lengths

# %%
lengths = [2, 4, 8, 16]
# holes = [1, 2, 4]
for length in lengths:
  train_loader = make_train_loader(make_train_set(make_transform(n_holes=1, length = length)))
  fine_tune(train_loader=train_loader, holes="length{}".format(length))
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Considering holes = length2
# Initial loss: 2.4257
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.4650, Training accuracy: 0.4544
# Validation loss: 1.3124, Validation accuracy: 0.5376
# Saving ...
#
# Epoch 1:
# Training loss: 1.0003, Training accuracy: 0.6408
# Validation loss: 1.2617, Validation accuracy: 0.5652
# Saving ...
#
# Epoch 2:
# Training loss: 0.8135, Training accuracy: 0.7132
# Validation loss: 0.9476, Validation accuracy: 0.6638
# Saving ...
#
# Epoch 3:
# Training loss: 0.6937, Training accuracy: 0.7562
# Validation loss: 0.8928, Validation accuracy: 0.6930
# Saving ...
#
# Epoch 4:
# Training loss: 0.6070, Training accuracy: 0.7887
# Validation loss: 0.7174, Validation accuracy: 0.7498
# Saving ...
#
# Epoch 5:
# Training loss: 0.5449, Training accuracy: 0.8109
# Validation loss: 0.6913, Validation accuracy: 0.7648
# Saving ...
#
# Epoch 6:
# Training loss: 0.4855, Training accuracy: 0.8317
# Validation loss: 0.7349, Validation accuracy: 0.7528
#
# Epoch 7:
# Training loss: 0.4402, Training accuracy: 0.8475
# Validation loss: 0.6801, Validation accuracy: 0.7746
# Saving ...
#
# Epoch 8:
# Training loss: 0.3965, Training accuracy: 0.8624
# Validation loss: 0.7445, Validation accuracy: 0.7574
#
# Epoch 9:
# Training loss: 0.3544, Training accuracy: 0.8755
# Validation loss: 0.6692, Validation accuracy: 0.7876
# Saving ...
#
# Epoch 10:
# Training loss: 0.3329, Training accuracy: 0.8827
# Validation loss: 0.8288, Validation accuracy: 0.7474
#
# Epoch 11:
# Training loss: 0.2891, Training accuracy: 0.8994
# Validation loss: 0.7159, Validation accuracy: 0.7864
#
# Epoch 12:
# Training loss: 0.2670, Training accuracy: 0.9070
# Validation loss: 0.6705, Validation accuracy: 0.7884
# Saving ...
#
# Epoch 13:
# Training loss: 0.2311, Training accuracy: 0.9185
# Validation loss: 0.8042, Validation accuracy: 0.7634
#
# Epoch 14:
# Training loss: 0.2100, Training accuracy: 0.9265
# Validation loss: 0.7273, Validation accuracy: 0.7838
#
# Epoch 15:
# Training loss: 0.1948, Training accuracy: 0.9311
# Validation loss: 0.7839, Validation accuracy: 0.7864
#
# Epoch 16:
# Training loss: 0.1752, Training accuracy: 0.9377
# Validation loss: 0.8333, Validation accuracy: 0.7694
#
# Epoch 17:
# Training loss: 0.1569, Training accuracy: 0.9442
# Validation loss: 0.8417, Validation accuracy: 0.7842
#
# Epoch 18:
# Training loss: 0.1365, Training accuracy: 0.9528
# Validation loss: 0.7943, Validation accuracy: 0.7900
# Saving ...
#
# Epoch 19:
# Training loss: 0.1279, Training accuracy: 0.9559
# Validation loss: 0.9085, Validation accuracy: 0.7752
#
# Epoch 20:
# Training loss: 0.1170, Training accuracy: 0.9588
# Validation loss: 0.8493, Validation accuracy: 0.7804
#
# Epoch 21:
# Training loss: 0.1037, Training accuracy: 0.9628
# Validation loss: 1.0071, Validation accuracy: 0.7540
#
# Epoch 22:
# Training loss: 0.0944, Training accuracy: 0.9672
# Validation loss: 0.9614, Validation accuracy: 0.7792
#
# Epoch 23:
# Training loss: 0.0786, Training accuracy: 0.9731
# Validation loss: 0.8812, Validation accuracy: 0.7924
# Saving ...
#
# Epoch 24:
# Training loss: 0.0748, Training accuracy: 0.9747
# Validation loss: 0.9235, Validation accuracy: 0.7934
# Saving ...
#
# Epoch 25:
# Training loss: 0.0768, Training accuracy: 0.9728
# Validation loss: 0.8859, Validation accuracy: 0.7974
# Saving ...
#
# Epoch 26:
# Training loss: 0.0688, Training accuracy: 0.9767
# Validation loss: 0.9403, Validation accuracy: 0.7946
#
# Epoch 27:
# Training loss: 0.0577, Training accuracy: 0.9808
# Validation loss: 0.9456, Validation accuracy: 0.7906
#
# Epoch 28:
# Training loss: 0.0664, Training accuracy: 0.9766
# Validation loss: 0.9904, Validation accuracy: 0.7910
#
# Epoch 29:
# Training loss: 0.0577, Training accuracy: 0.9805
# Validation loss: 1.0581, Validation accuracy: 0.7846
#
# Epoch 30:
# Training loss: 0.0516, Training accuracy: 0.9832
# Validation loss: 1.0092, Validation accuracy: 0.7890
#
# Epoch 31:
# Training loss: 0.0441, Training accuracy: 0.9849
# Validation loss: 1.0071, Validation accuracy: 0.7914
#
# Epoch 32:
# Training loss: 0.0479, Training accuracy: 0.9830
# Validation loss: 0.9866, Validation accuracy: 0.7932
#
# Epoch 33:
# Training loss: 0.0421, Training accuracy: 0.9859
# Validation loss: 1.0620, Validation accuracy: 0.7830
#
# Epoch 34:
# Training loss: 0.0454, Training accuracy: 0.9847
# Validation loss: 0.9538, Validation accuracy: 0.8040
# Saving ...
#
# Epoch 35:
# Training loss: 0.0371, Training accuracy: 0.9878
# Validation loss: 0.9920, Validation accuracy: 0.8010
#
# Epoch 36:
# Training loss: 0.0318, Training accuracy: 0.9892
# Validation loss: 0.9085, Validation accuracy: 0.8080
# Saving ...
#
# Epoch 37:
# Training loss: 0.0284, Training accuracy: 0.9911
# Validation loss: 0.9934, Validation accuracy: 0.8004
#
# Epoch 38:
# Training loss: 0.0245, Training accuracy: 0.9924
# Validation loss: 0.9679, Validation accuracy: 0.8108
# Saving ...
#
# Epoch 39:
# Training loss: 0.0253, Training accuracy: 0.9920
# Validation loss: 1.0392, Validation accuracy: 0.7982
#
# Epoch 40:
# Training loss: 0.0330, Training accuracy: 0.9887
# Validation loss: 0.9960, Validation accuracy: 0.8018
#
# Epoch 41:
# Training loss: 0.0302, Training accuracy: 0.9901
# Validation loss: 1.1061, Validation accuracy: 0.7898
#
# Epoch 42:
# Training loss: 0.0353, Training accuracy: 0.9878
# Validation loss: 1.0376, Validation accuracy: 0.7988
#
# Epoch 43:
# Training loss: 0.0311, Training accuracy: 0.9891
# Validation loss: 1.0680, Validation accuracy: 0.8054
#
# Epoch 44:
# Training loss: 0.0272, Training accuracy: 0.9909
# Validation loss: 1.0327, Validation accuracy: 0.8044
#
# Epoch 45:
# Training loss: 0.0266, Training accuracy: 0.9914
# Validation loss: 1.0345, Validation accuracy: 0.7996
#
# Epoch 46:
# Training loss: 0.0256, Training accuracy: 0.9913
# Validation loss: 1.0585, Validation accuracy: 0.8036
#
# Epoch 47:
# Training loss: 0.0247, Training accuracy: 0.9920
# Validation loss: 1.1308, Validation accuracy: 0.7940
#
# Epoch 48:
# Training loss: 0.0235, Training accuracy: 0.9923
# Validation loss: 1.0421, Validation accuracy: 0.8042
#
# Epoch 49:
# Training loss: 0.0155, Training accuracy: 0.9953
# Validation loss: 1.0237, Validation accuracy: 0.8136
# Saving ...
#
# Epoch 50:
# Training loss: 0.0133, Training accuracy: 0.9959
# Validation loss: 1.1041, Validation accuracy: 0.7982
#
# Epoch 51:
# Training loss: 0.0161, Training accuracy: 0.9947
# Validation loss: 1.0535, Validation accuracy: 0.8056
#
# Epoch 52:
# Training loss: 0.0139, Training accuracy: 0.9961
# Validation loss: 1.0693, Validation accuracy: 0.8054
#
# Epoch 53:
# Training loss: 0.0163, Training accuracy: 0.9947
# Validation loss: 1.0525, Validation accuracy: 0.8090
#
# Epoch 54:
# Training loss: 0.0164, Training accuracy: 0.9948
# Validation loss: 1.1740, Validation accuracy: 0.7962
#
# Epoch 55:
# Training loss: 0.0176, Training accuracy: 0.9944
# Validation loss: 1.2964, Validation accuracy: 0.7838
#
# Epoch 56:
# Training loss: 0.0179, Training accuracy: 0.9946
# Validation loss: 1.1110, Validation accuracy: 0.8054
#
# Epoch 57:
# Training loss: 0.0150, Training accuracy: 0.9956
# Validation loss: 1.0913, Validation accuracy: 0.8056
#
# Epoch 58:
# Training loss: 0.0139, Training accuracy: 0.9954
# Validation loss: 1.1165, Validation accuracy: 0.8026
#
# Epoch 59:
# Training loss: 0.0151, Training accuracy: 0.9950
# Validation loss: 1.0869, Validation accuracy: 0.8086
#
# Epoch 60:
# Training loss: 0.0136, Training accuracy: 0.9956
# Validation loss: 1.0672, Validation accuracy: 0.8168
# Saving ...
#
# Epoch 61:
# Training loss: 0.0163, Training accuracy: 0.9948
# Validation loss: 1.0670, Validation accuracy: 0.8108
#
# Epoch 62:
# Training loss: 0.0225, Training accuracy: 0.9924
# Validation loss: 1.1241, Validation accuracy: 0.7994
#
# Epoch 63:
# Training loss: 0.0171, Training accuracy: 0.9944
# Validation loss: 1.1121, Validation accuracy: 0.7992
#
# Epoch 64:
# Training loss: 0.0173, Training accuracy: 0.9944
# Validation loss: 1.0779, Validation accuracy: 0.8144
#
# Epoch 65:
# Training loss: 0.0125, Training accuracy: 0.9963
# Validation loss: 1.1072, Validation accuracy: 0.8124
#
# Epoch 66:
# Training loss: 0.0134, Training accuracy: 0.9955
# Validation loss: 1.0726, Validation accuracy: 0.8086
#
# Epoch 67:
# Training loss: 0.0112, Training accuracy: 0.9965
# Validation loss: 1.1497, Validation accuracy: 0.8086
#
# Epoch 68:
# Training loss: 0.0123, Training accuracy: 0.9966
# Validation loss: 1.0810, Validation accuracy: 0.8120
#
# Epoch 69:
# Training loss: 0.0136, Training accuracy: 0.9955
# Validation loss: 1.0824, Validation accuracy: 0.8144
#
# Epoch 70:
# Training loss: 0.0087, Training accuracy: 0.9977
# Validation loss: 1.1155, Validation accuracy: 0.8104
#
# Epoch 71:
# Training loss: 0.0147, Training accuracy: 0.9956
# Validation loss: 1.1388, Validation accuracy: 0.8036
#
# Epoch 72:
# Training loss: 0.0126, Training accuracy: 0.9960
# Validation loss: 1.0667, Validation accuracy: 0.8162
#
# Epoch 73:
# Training loss: 0.0118, Training accuracy: 0.9964
# Validation loss: 1.2458, Validation accuracy: 0.7978
#
# Epoch 74:
# Training loss: 0.0085, Training accuracy: 0.9974
# Validation loss: 1.1302, Validation accuracy: 0.8108
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8168
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Considering holes = length4
# Initial loss: 2.3806
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.4962, Training accuracy: 0.4454
# Validation loss: 1.6186, Validation accuracy: 0.4516
# Saving ...
#
# Epoch 1:
# Training loss: 1.0181, Training accuracy: 0.6366
# Validation loss: 1.1680, Validation accuracy: 0.5930
# Saving ...
#
# Epoch 2:
# Training loss: 0.8222, Training accuracy: 0.7066
# Validation loss: 0.8503, Validation accuracy: 0.7012
# Saving ...
#
# Epoch 3:
# Training loss: 0.6989, Training accuracy: 0.7556
# Validation loss: 0.8128, Validation accuracy: 0.7082
# Saving ...
#
# Epoch 4:
# Training loss: 0.6163, Training accuracy: 0.7834
# Validation loss: 0.6916, Validation accuracy: 0.7624
# Saving ...
#
# Epoch 5:
# Training loss: 0.5514, Training accuracy: 0.8072
# Validation loss: 0.6929, Validation accuracy: 0.7608
#
# Epoch 6:
# Training loss: 0.4998, Training accuracy: 0.8252
# Validation loss: 0.7125, Validation accuracy: 0.7594
#
# Epoch 7:
# Training loss: 0.4543, Training accuracy: 0.8406
# Validation loss: 0.6548, Validation accuracy: 0.7872
# Saving ...
#
# Epoch 8:
# Training loss: 0.4171, Training accuracy: 0.8548
# Validation loss: 0.6263, Validation accuracy: 0.7934
# Saving ...
#
# Epoch 9:
# Training loss: 0.3860, Training accuracy: 0.8656
# Validation loss: 0.7052, Validation accuracy: 0.7692
#
# Epoch 10:
# Training loss: 0.3429, Training accuracy: 0.8809
# Validation loss: 0.6751, Validation accuracy: 0.7790
#
#
# Epoch 59:
# Training loss: 0.0201, Training accuracy: 0.9934
# Validation loss: 1.0479, Validation accuracy: 0.8102
#
# Epoch 60:
# Training loss: 0.0258, Training accuracy: 0.9915
# Validation loss: 1.0325, Validation accuracy: 0.8090
#
# Epoch 61:
# Training loss: 0.0259, Training accuracy: 0.9912
# Validation loss: 1.0395, Validation accuracy: 0.8102
#
# Epoch 62:
# Training loss: 0.0237, Training accuracy: 0.9923
# Validation loss: 0.9259, Validation accuracy: 0.8218
#
# Epoch 63:
# Training loss: 0.0242, Training accuracy: 0.9919
# Validation loss: 0.9755, Validation accuracy: 0.8206
#
# Epoch 64:
# Training loss: 0.0230, Training accuracy: 0.9920
# Validation loss: 1.0512, Validation accuracy: 0.8080
#
# Epoch 65:
# Training loss: 0.0249, Training accuracy: 0.9914
# Validation loss: 0.9434, Validation accuracy: 0.8142
#
# Epoch 66:
# Training loss: 0.0250, Training accuracy: 0.9912
# Validation loss: 0.9603, Validation accuracy: 0.8238
#
# Epoch 67:
# Training loss: 0.0245, Training accuracy: 0.9922
# Validation loss: 0.9645, Validation accuracy: 0.8170
#
# Epoch 68:
# Training loss: 0.0227, Training accuracy: 0.9931
# Validation loss: 0.9876, Validation accuracy: 0.8160
#
# Epoch 69:
# Training loss: 0.0225, Training accuracy: 0.9925
# Validation loss: 0.9763, Validation accuracy: 0.8178
#
# Epoch 70:
# Training loss: 0.0246, Training accuracy: 0.9919
# Validation loss: 1.0612, Validation accuracy: 0.8058
#
# Epoch 71:
# Training loss: 0.0189, Training accuracy: 0.9939
# Validation loss: 0.9765, Validation accuracy: 0.8216
#
# Epoch 72:
# Training loss: 0.0236, Training accuracy: 0.9926
# Validation loss: 0.9818, Validation accuracy: 0.8142
#
# Epoch 73:
# Training loss: 0.0186, Training accuracy: 0.9936
# Validation loss: 0.9857, Validation accuracy: 0.8160
#
# Epoch 74:
# Training loss: 0.0188, Training accuracy: 0.9941
# Validation loss: 0.9474, Validation accuracy: 0.8200
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8242
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Considering holes = length8
# Initial loss: 2.5741
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.4994, Training accuracy: 0.4436
# Validation loss: 1.5379, Validation accuracy: 0.4672
# Saving ...
#
# Epoch 1:
# Training loss: 1.0485, Training accuracy: 0.6208
# Validation loss: 1.0830, Validation accuracy: 0.6196
# Saving ...
#
# Epoch 2:
# Training loss: 0.8689, Training accuracy: 0.6898
# Validation loss: 0.9546, Validation accuracy: 0.6580
# Saving ...
#
# Epoch 3:
# Training loss: 0.7552, Training accuracy: 0.7322
# Validation loss: 1.1629, Validation accuracy: 0.6118
#
# Epoch 4:
# Training loss: 0.6647, Training accuracy: 0.7671
# Validation loss: 0.8362, Validation accuracy: 0.7210
# Saving ...
#
# Epoch 5:
# Training loss: 0.6168, Training accuracy: 0.7840
#
# Epoch 53:
# Training loss: 0.0656, Training accuracy: 0.9773
# Validation loss: 0.8986, Validation accuracy: 0.8060
#
# Epoch 54:
# Training loss: 0.0694, Training accuracy: 0.9758
# Validation loss: 0.8133, Validation accuracy: 0.8216
#
# Epoch 55:
# Training loss: 0.0597, Training accuracy: 0.9797
# Validation loss: 0.8668, Validation accuracy: 0.8108
#
# Epoch 56:
# Training loss: 0.0638, Training accuracy: 0.9784
# Validation loss: 0.8682, Validation accuracy: 0.8186
#
# Epoch 57:
# Training loss: 0.0613, Training accuracy: 0.9793
# Validation loss: 0.8206, Validation accuracy: 0.8228
#
# Epoch 58:
# Training loss: 0.0600, Training accuracy: 0.9797
# Validation loss: 0.9035, Validation accuracy: 0.8108
#
# Epoch 59:
# Training loss: 0.0558, Training accuracy: 0.9814
# Validation loss: 0.8540, Validation accuracy: 0.8192
#
# Epoch 60:
# Training loss: 0.0571, Training accuracy: 0.9808
# Validation loss: 0.9400, Validation accuracy: 0.8042
#
# Epoch 61:
# Training loss: 0.0576, Training accuracy: 0.9806
# Validation loss: 0.8660, Validation accuracy: 0.8178
#
# Epoch 62:
# Training loss: 0.0549, Training accuracy: 0.9808
# Validation loss: 0.8069, Validation accuracy: 0.8212
#
# Epoch 63:
# Training loss: 0.0559, Training accuracy: 0.9809
# Validation loss: 0.8086, Validation accuracy: 0.8262
# Saving ...
#
# Epoch 64:
# Training loss: 0.0508, Training accuracy: 0.9830
# Validation loss: 0.8762, Validation accuracy: 0.8148
#
# Epoch 65:
# Training loss: 0.0548, Training accuracy: 0.9807
# Validation loss: 0.8686, Validation accuracy: 0.8172
#
# Epoch 66:
# Training loss: 0.0543, Training accuracy: 0.9811
# Validation loss: 0.8392, Validation accuracy: 0.8186
#
# Epoch 67:
# Training loss: 0.0532, Training accuracy: 0.9820
# Validation loss: 0.8765, Validation accuracy: 0.8176
#
# Epoch 68:
# Training loss: 0.0516, Training accuracy: 0.9832
# Validation loss: 0.8735, Validation accuracy: 0.8174
#
# Epoch 69:
# Training loss: 0.0498, Training accuracy: 0.9835
# Validation loss: 0.8546, Validation accuracy: 0.8246
#
# Epoch 70:
# Training loss: 0.0488, Training accuracy: 0.9830
# Validation loss: 0.9019, Validation accuracy: 0.8112
#
# Epoch 71:
# Training loss: 0.0520, Training accuracy: 0.9825
# Validation loss: 0.9127, Validation accuracy: 0.8126
#
# Epoch 72:
# Training loss: 0.0487, Training accuracy: 0.9836
# Validation loss: 0.8486, Validation accuracy: 0.8156
#
# Epoch 73:
# Training loss: 0.0491, Training accuracy: 0.9832
# Validation loss: 0.8268, Validation accuracy: 0.8274
# Saving ...
#
# Epoch 74:
# Training loss: 0.0458, Training accuracy: 0.9845
# Validation loss: 0.8418, Validation accuracy: 0.8168
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8274
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Considering holes = length16
# Initial loss: 2.3715
#
# Epoch 71:
# Training loss: 0.1530, Training accuracy: 0.9452
# Validation loss: 0.7015, Validation accuracy: 0.8334
#
# Epoch 72:
# Training loss: 0.1454, Training accuracy: 0.9481
# Validation loss: 0.7621, Validation accuracy: 0.8256
#
# Epoch 73:
# Training loss: 0.1396, Training accuracy: 0.9506
# Validation loss: 0.7555, Validation accuracy: 0.8192
#
# Epoch 74:
# Training loss: 0.1411, Training accuracy: 0.9512
# Validation loss: 0.7950, Validation accuracy: 0.8248
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8360

# %%
# lengths = [2, 4, 8, 16]
holes = [1, 2, 4]
for hole in holes:
  train_loader = make_train_loader(make_train_set(make_transform(n_holes=hole, length = 2)))
  fine_tune(train_loader=train_loader, holes="holes{}".format(hole))
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Considering holes = holes1
# Initial loss: 2.4415
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.4667, Training accuracy: 0.4568
# Validation loss: 1.2252, Validation accuracy: 0.5480
# Saving ...
#
# Epoch 1:
# Training loss: 1.0148, Training accuracy: 0.6345
# Validation loss: 0.9756, Validation accuracy: 0.6536
# Saving ...
#
# Epoch 2:
# Training loss: 0.8174, Training accuracy: 0.7127
# Validation loss: 0.9620, Validation accuracy: 0.6692
# Saving ...
#
# Epoch 3:
# Training loss: 0.6946, Training accuracy: 0.7566
# Validation loss: 0.7653, Validation accuracy: 0.7258
# Saving ...
#
# Epoch 4:
# Training loss: 0.6050, Training accuracy: 0.7882
# Validation loss: 0.8444, Validation accuracy: 0.7050
#
# Epoch 5:
# Training loss: 0.5383, Training accuracy: 0.8126
# Validation loss: 0.8487, Validation accuracy: 0.7152
#
# Epoch 6:
# Training loss: 0.4819, Training accuracy: 0.8314
# Validation loss: 0.6869, Validation accuracy: 0.7720
# Saving ...
#
# Epoch 7:
# Training loss: 0.4440, Training accuracy: 0.8443
# Validation loss: 0.7861, Validation accuracy: 0.7482
#
# Epoch 8:
# Training loss: 0.3958, Training accuracy: 0.8612
# Validation loss: 0.5946, Validation accuracy: 0.7952
# Saving ...
#
# Epoch 9:
# Training loss: 0.3564, Training accuracy: 0.8748
# Validation loss: 0.6203, Validation accuracy: 0.7936
#
# Epoch 10:
# Training loss: 0.3256, Training accuracy: 0.8841
# Validation loss: 0.7204, Validation accuracy: 0.7662
#
# Epoch 11:
# Training loss: 0.3013, Training accuracy: 0.8954
# Validation loss: 0.6992, Validation accuracy: 0.7746
#
# Epoch 12:
# Training loss: 0.2714, Training accuracy: 0.9037
# Validation loss: 0.8149, Validation accuracy: 0.7542
#
# Epoch 13:
# Training loss: 0.2470, Training accuracy: 0.9130
# Validation loss: 0.7460, Validation accuracy: 0.7754
#
# Epoch 14:
# Training loss: 0.2204, Training accuracy: 0.9207
# Validation loss: 0.6848, Validation accuracy: 0.7896
#
# Epoch 15:
# Training loss: 0.1945, Training accuracy: 0.9311
# Validation loss: 1.0854, Validation accuracy: 0.8060
#
# Epoch 64:
# Training loss: 0.0134, Training accuracy: 0.9959
# Validation loss: 1.0108, Validation accuracy: 0.8132
#
# Epoch 65:
# Training loss: 0.0126, Training accuracy: 0.9960
# Validation loss: 1.0458, Validation accuracy: 0.8074
#
# Epoch 66:
# Training loss: 0.0123, Training accuracy: 0.9959
# Validation loss: 1.0155, Validation accuracy: 0.8164
# Saving ...
#
# Epoch 67:
# Training loss: 0.0141, Training accuracy: 0.9956
# Validation loss: 1.2116, Validation accuracy: 0.7942
#
# Epoch 68:
# Training loss: 0.0142, Training accuracy: 0.9957
# Validation loss: 1.1433, Validation accuracy: 0.8046
#
# Epoch 69:
# Training loss: 0.0108, Training accuracy: 0.9969
# Validation loss: 1.0434, Validation accuracy: 0.8156
#
# Epoch 70:
# Training loss: 0.0077, Training accuracy: 0.9977
# Validation loss: 1.0735, Validation accuracy: 0.8104
#
# Epoch 71:
# Training loss: 0.0101, Training accuracy: 0.9968
# Validation loss: 1.0768, Validation accuracy: 0.8102
#
# Epoch 72:
# Training loss: 0.0122, Training accuracy: 0.9961
# Validation loss: 1.1036, Validation accuracy: 0.8084
#
# Epoch 73:
# Training loss: 0.0154, Training accuracy: 0.9952
# Validation loss: 1.1016, Validation accuracy: 0.8024
#
# Epoch 74:
# Training loss: 0.0128, Training accuracy: 0.9960
# Validation loss: 1.0790, Validation accuracy: 0.8132
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8164
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Considering holes = holes2
# Initial loss: 2.6081
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.5047, Training accuracy: 0.4386
# Validation loss: 1.6346, Validation accuracy: 0.4286
# Saving ...
#
# Epoch 1:
# Training loss: 1.0374, Training accuracy: 0.6273
# Validation loss: 1.0834, Validation accuracy: 0.6126
# Saving ...
#
# Epoch 2:
# Training loss: 0.8298, Training accuracy: 0.7051
# Validation loss: 0.8584, Validation accuracy: 0.7002
# Saving ...
#
# Epoch 3:
# Training loss: 0.7059, Training accuracy: 0.7510
# Validation loss: 0.8029, Validation accuracy: 0.7254
# Saving ...
#
# Epoch 4:
# Training loss: 0.6160, Training accuracy: 0.7838
# Validation loss: 0.6725, Validation accuracy: 0.7672
# Saving ...
#
# Epoch 5:
# Training loss: 0.5473, Training accuracy: 0.8092
# Validation loss: 0.6906, Validation accuracy: 0.7686
# Saving ...
#
# Epoch 6:
# Training loss: 0.4935, Training accuracy: 0.8273
# Validation loss: 0.6494, Validation accuracy: 0.7810
# Saving ...
#
# Epoch 7:
# Training loss: 0.4484, Training accuracy: 0.8439
# Validation loss: 0.6989, Validation accuracy: 0.7656
#
# Epoch 8:
# Training loss: 0.4042, Training accuracy: 0.8594
# Validation loss: 0.6742, Validation accuracy: 0.7758
#
# Epoch 9:
# Training loss: 0.3650, Training accuracy: 0.8722
# Validation loss: 0.6712, Validation accuracy: 0.7848
# Validation loss: 1.0666, Validation accuracy: 0.8056
#
# Epoch 58:
# Training loss: 0.0217, Training accuracy: 0.9927
# Validation loss: 1.0168, Validation accuracy: 0.8140
#
# Epoch 59:
# Training loss: 0.0217, Training accuracy: 0.9928
# Validation loss: 1.1281, Validation accuracy: 0.7998
#
# Epoch 60:
# Training loss: 0.0180, Training accuracy: 0.9942
# Validation loss: 1.0257, Validation accuracy: 0.8086
#
# Epoch 61:
# Training loss: 0.0153, Training accuracy: 0.9952
# Validation loss: 1.0191, Validation accuracy: 0.8164
# Saving ...
#
# Epoch 62:
# Training loss: 0.0125, Training accuracy: 0.9965
# Validation loss: 1.0985, Validation accuracy: 0.8076
#
# Epoch 63:
# Training loss: 0.0139, Training accuracy: 0.9956
# Validation loss: 1.0666, Validation accuracy: 0.8090
#
# Epoch 64:
# Training loss: 0.0128, Training accuracy: 0.9965
# Validation loss: 1.0919, Validation accuracy: 0.8078
#
# Epoch 65:
# Training loss: 0.0132, Training accuracy: 0.9963
# Validation loss: 1.0906, Validation accuracy: 0.8070
#
# Epoch 66:
# Training loss: 0.0145, Training accuracy: 0.9953
# Validation loss: 1.1390, Validation accuracy: 0.8056
#
# Epoch 67:
# Training loss: 0.0159, Training accuracy: 0.9946
# Validation loss: 1.1457, Validation accuracy: 0.8076
#
# Epoch 68:
# Training loss: 0.0160, Training accuracy: 0.9948
# Validation loss: 1.1332, Validation accuracy: 0.8038
#
# Epoch 69:
# Training loss: 0.0192, Training accuracy: 0.9937
# Validation loss: 1.1018, Validation accuracy: 0.8060
#
# Epoch 70:
# Training loss: 0.0161, Training accuracy: 0.9951
# Validation loss: 1.0693, Validation accuracy: 0.8130
#
# Epoch 71:
# Training loss: 0.0150, Training accuracy: 0.9953
# Validation loss: 1.1835, Validation accuracy: 0.7972
#
# Epoch 72:
# Training loss: 0.0133, Training accuracy: 0.9959
# Validation loss: 1.1272, Validation accuracy: 0.8142
#
# Epoch 73:
# Training loss: 0.0161, Training accuracy: 0.9944
# Validation loss: 1.0578, Validation accuracy: 0.8136
#
# Epoch 74:
# Training loss: 0.0167, Training accuracy: 0.9944
# Validation loss: 1.0670, Validation accuracy: 0.8188
# Saving ...
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8188
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Considering holes = holes4
# Initial loss: 2.3113
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.4862, Training accuracy: 0.4451
# Validation loss: 1.4405, Validation accuracy: 0.5144
# Saving ...
#
# Epoch 1:
# Training loss: 1.0256, Training accuracy: 0.6337
# Validation loss: 1.2244, Validation accuracy: 0.5726
# Saving ...
#
# Epoch 2:
# Training loss: 0.8365, Training accuracy: 0.7046
# Validation loss: 0.9035, Validation accuracy: 0.6834
# Saving ...
#
# Epoch 3:
# Training loss: 0.7169, Training accuracy: 0.7468
# Validation loss: 0.9312, Validation accuracy: 0.6808
