# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys 
sys.path.append('/content/drive/MyDrive/ECE_661/661_Final_Project')

# %%
# import necessary dependencies
import argparse
import os
import time
import tools
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np

# %%
# define the ResBlock to be used in ResNet;
class ResBlock(nn.Module):
    def __init__(self, input_dim, output_dim, k_size=3, stride_bool=False):
        super(ResBlock, self).__init__()
        if(stride_bool == True):
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, stride=2, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1, stride=2)
        else:
          self.conv1 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
          self.resconv = nn.Conv2d(input_dim, output_dim, kernel_size=1)

        if input_dim != output_dim:
          input_dim = output_dim
        self.bn1 = nn.BatchNorm2d(output_dim)
        self.conv2 = nn.Conv2d(input_dim, output_dim, kernel_size=k_size, padding=1)
        self.bn2 = nn.BatchNorm2d(output_dim)

    def forward(self, x):
        y = x
      # Note shortcut will just be x if of same shape as out
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out)) 
        if (x.shape == out.shape):
          out = out + y
          out = F.relu(out)
          return out
        else:
          y = self.resconv(y)
          out = out.add(y)
          out = F.relu(out)
          return out

# %%
class ResNet(nn.Module):
  def __init__(self):
    super(ResNet, self).__init__()
    self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
    self.bn1 = nn.BatchNorm2d(16)
    # 16 filter res blockss
    self.res1 = ResBlock(16, 16)
    self.res2 = ResBlock(16, 16)
    self.res3 = ResBlock(16, 16)
    # Now 32 filter res blocks
    self.res4 = ResBlock(16, 32, stride_bool=True)
    self.res5 = ResBlock(32, 32)
    self.res6 = ResBlock(32, 32)
    # Now 64 filter res blocks 
    self.res7 = ResBlock(32, 64, stride_bool=True)
    self.res8 = ResBlock(64, 64)
    self.res9 = ResBlock(64, 64)

    self.fc = nn.Linear(64, 10)
    self.fc2 = nn.Linear(64,4)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))

    # ReLU contained within forward method of res blocks
    
    out = self.res1(out)
    out = self.res2(out)
    out = self.res3(out)

    out = self.res4(out)
    out = self.res5(out)
    out = self.res6(out)

    out = self.res7(out)
    out = self.res8(out)
    out = self.res9(out)

    out = F.adaptive_avg_pool2d(out, 1)
    out = out.view(out.size(0), -1)
    outt = self.fc(out)
    outr = self.fc2(out)
    # out = F.softmax(out)
    return outt, outr

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([transforms.ToTensor(),
                                      # transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010)),
                                     # transforms.RandomCrop(size=(32,32), padding=4),
                                      # transforms.RandomHorizontalFlip(), 
                                      # transforms.RandomRotation(degrees=15)
]) 
                                      # transforms.GaussianBlur(kernel_size=5, sigma = 0.5)])

transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))])
#############################################

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
# do NOT change these
#import tools
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 256
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train    # your code
)

val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val    # your code
)

# construct dataloader
# train_loader = DataLoader(
#     train_set, 
#     batch_size=256,  # your code
#     shuffle=True,     # your code
#     num_workers=4
# )
# val_loader = DataLoader(
#     val_set, 
#     batch_size=256,  # your code
#     shuffle=False,     # your code
#     num_workers=4
# )
#############################################
# Out:
# Downloading https://www.dropbox.com/s/s8orza214q45b23/cifar10_trainval_F22.zip?dl=1 to ./data/cifar10_trainval_F22.zip
# 0it [00:00, ?it/s]
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %%
# PERTURB OUR TRAINING DATA HERE
inputs_changed = []
targets_changed = []
i = 0
print(type(train_set))
for inputs, targets in train_set:
  # print(inputs.shape, targets)
  #print(inputs.type)

  inputs = inputs.detach().numpy()
  input0 = inputs
  # input1 = np.rot90(inputs, 1, axes=(1,2))
  # input2 = np.rot90(inputs, 2, axes=(1,2))
  # input3 = np.rot90(inputs, 3, axes=(1,2))
  inputs_changed.append(input0)
  # inputs_changed.append(input1)
  # inputs_changed.append(input2)
  # inputs_changed.append(input3)
  targets_changed.append([targets] + [0])
  # targets_changed.append([targets] + [1])
  # targets_changed.append([targets] + [2])
  # targets_changed.append([targets]+ [3])
  i += 1
  # if i ==10:
  #   break
# print(train_set)
# Out:
# <class 'tools.dataset.CIFAR10'>

# %%
# # PERTURB OUR TRAINING DATA HERE
# print('this is trying to create the stacked ones')
# inputs_changed = []
# targets_changed = []
# i = 0
# for inputs, targets in train_set:
#   # print(inputs.shape, targets)
#   # print(i)
#   inputs = inputs.numpy()
#   input = np.concatenate((inputs, np.rot90(inputs, 1, axes=(1,2)), np.rot90(inputs, 2, axes =(1,2)), np.rot90(inputs, 3, axes = (1,2))), 0)
#   inputs_changed.append(input)
#   target = np.vstack(([targets] + [0], [targets] + [1], [targets] + [2], [targets] + [3]))
#   targets_changed.append(target)
#   i += 1
# # print(train_set)

# %%
print(targets_changed[0])
# Out:
# [1, 0]

# %%
inputs_changed = np.array(inputs_changed, dtype = 'float64')
targets_changed = np.array(targets_changed)

# print('HEY LUIS I MADE A CHANGE HERE - THE TWO LINES ABOVE USED TO BE COMMENTED OUT, BUT THIS MORNING I HAD TO UNCOMMENT THEM')
# inputs_changed[0].shape
# print(targets_changed.shape)

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here
# GPU check                
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")
  
    
#############################################
# Out:
# Run on GPU...

# %%
from torch.utils.data import TensorDataset
features = torch.from_numpy(inputs_changed).type(torch.float32)
labels = torch.from_numpy(targets_changed)

training_set = TensorDataset(features,labels)

# CIFAR10( --- Was trying to see if there was a way we could transform after perturbing, but doesn't seem to be the case
#     root=DATA_ROOT, 
#     mode='train', 
#     download=True,
#     transform=transform_train    # your code
# )

# %%
train_loader = DataLoader(
    training_set, 
    batch_size=256,  # your code
    shuffle=True,     # your code
    num_workers=4
)

val_loader = DataLoader(
    val_set, 
    batch_size=256,  # your code
    shuffle=False,     # your code
    num_workers=4
)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# !nvidia-smi
# Out:
# Tue Dec 13 06:28:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P0    28W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

net = ResNet().to(device)
# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-5

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss().to(device)

# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay = REG) #momentum value from AlexNet
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities?)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %% [markdown]
# ## Only data augmentation

# %%
# Just data augmentation

# total number of training epochs
EPOCHS = 200
 
lam = .5
# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

# Calculate initial loss 
initial_loss = 0
for batch_idx, (inputs, targets) in enumerate(train_loader):
  # print(inputs[:,:3,:,:].shape)
  inputs = inputs.to(device)
  targets = targets.to(device)
  
  # compute the output and loss
  # outputs = net(inputs[:,:3,:,:]) #this is how to seperate out images - this will be the unrotated image
  outputs = net(inputs)
  if batch_idx ==1:
    print('initial loss from each head makes sense! Goood news')
    # print((outputs[0][1]))
    # print(max(targets[:,0]))
    # print(min(targets[:,1]))
    # print(outputs[0][1])
  # print(targets.shape)
  initial_loss_10 = criterion(outputs[0], targets[:,0]) #these targets will be the tuple that corresponds to the unrotated image! - CHANGED FOR THE BASE CASE
  # initial_loss_4 = criterion(outputs[1], targets[:,1])
  # initial_loss += loss
print("Initial loss for classi: %.4f" %(initial_loss_10))
# print("Initial loss for rotay: %.4f" %(initial_loss_4))

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
#     # handle the learning rate scheduler.
  #  if i % DECAY_EPOCHS == 0 and i != 0:
#         current_learning_rate = current_learning_rate * DECAY
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = current_learning_rate
#         print("Current learning rate has decayed to %f" %current_learning_rate)
    if 140 > i > 100  :
      current_learning_rate = 0.1
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
      print("Current learning rate has decayed to %f" %current_learning_rate)
    if 170 > i > 140  :
      current_learning_rate = 0.01
      momentum = 0.6
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
          param_group['momentum'] = momentum
      print("Current learning rate has decayed to %f" %current_learning_rate)
    if i > 170  :
      current_learning_rate = 0.001
      momentum = 0.3
      for param_group in optimizer.param_groups:
          param_group['lr'] = current_learning_rate
          param_group['momentum'] = momentum
      print("Current learning rate has decayed to %f" %current_learning_rate)
    
    
    #######################
    # your code here
    # switch to train mode
    net.train()
    #######################

    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # compute the output and loss
        output = net(inputs)
        # output0 = net(inputs[:,:3,:,:])
        # output90 = net(inputs[:,3:6,:,:])
        # output180 = net(inputs[:,6:9,:,:])
        # output270 = net(inputs[:,9:12,:,:]) # This is admittedly naive - but we are doing it this way so our net is easily adapated to combine the image pertubation methods!
        
        loss = criterion(output[0], targets[:,0])
        # loss = criterion(output0[0], targets[:,0,0]) # this is loss from classification head on unrotated image
        # loss += lam * .25* criterion(output0[1], targets[:,0,1]) #now adding in weighted rotation loss for unrotated
        # loss += lam * .25* criterion(output90[1], targets[:,1,1]) #again, weighted rotation loss for 90 degree
        # loss += lam * .25* criterion(output180[1], targets[:,2,1]) #again, weighted rotation loss for 180 degree
        # loss += lam * .25* criterion(output270[1], targets[:,3,1]) #again, weighted rotation loss for 270 degree
        
          
        train_loss += loss
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly classified samples in the current batch
        _, predicted = torch.max(output[0], 1) 


        ###


        ## THIS RIGHT HERE, UNSURE ABOUT, DIRECT ABOVE< IS THIS RIGHT? IS THIS WRONG? I DON'T KNOW
        # line with the torch.max, used to just be outputs, not outputs[0]
        #also for the line below, is this correct? - I think I am only looking at percetange of correct for our image classification
        # not also considering percet correct for our  rotations (i.e only seeing if predicted right, not predicted right and rotation right)



        ###
        correct = predicted.eq(targets[:,0]).sum()

        total_examples += targets.shape[0]
        correct_examples += correct.item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # compute the output and loss
            outputs = net(inputs)
            val_loss += criterion(outputs[0], targets)
            
            # count the number of correctly predicted samples in the current batch





            #####


            #ALSO THE PART BELOW HERE, SAME QUESTION AS DURING TRAINING


            #######
            _, predicted = torch.max(outputs[0], 1)
            correct = predicted.eq(targets).sum()

            total_examples += targets.shape[0]
            correct_examples += correct.item()
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_FOLDER):
           os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': net.state_dict(),
                'epoch': i,
                'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'resnet_auxrot.pth'))
        # model.load_state_dict(state_dict["state_dict"])
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# this is now only considering the loss as a result of our rotation head - i.e we need to feed it a model that was already trained on its classification head!
# so we need to load in our pre trained model for this guy
# also our hyper parameter is how much we weight our loss by in this setting
# initial loss from each head makes sense! Goood news
# Initial loss for classi: 2.5759
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.7304, Training accuracy: 0.3484
# Validation loss: 1.8479, Validation accuracy: 0.3942
# Saving ...
#
# Epoch 1:
# Training loss: 1.3671, Training accuracy: 0.4987
# Validation loss: 1.4180, Validation accuracy: 0.4922
# Saving ...
#
# Epoch 2:
# Training loss: 1.1396, Training accuracy: 0.5878
# Validation loss: 1.4036, Validation accuracy: 0.5392
# Saving ...
#
# Epoch 3:
# Training loss: 0.9809, Training accuracy: 0.6496
# Validation loss: 0.9532, Validation accuracy: 0.6626
# Saving ...
#
# Epoch 4:
# Training loss: 0.8559, Training accuracy: 0.6972
# Validation loss: 0.9509, Validation accuracy: 0.6768
# Saving ...
#
# Epoch 5:
# Training loss: 0.7595, Training accuracy: 0.7344
# Validation loss: 0.9190, Validation accuracy: 0.6960
# Saving ...
#
# Epoch 6:
# Training loss: 0.6839, Training accuracy: 0.7591
# Validation loss: 0.8516, Validation accuracy: 0.7164
# Saving ...
#
# Epoch 7:
# Training loss: 0.6192, Training accuracy: 0.7818
# Validation loss: 0.9552, Validation accuracy: 0.7040
#
# Epoch 8:
# Training loss: 0.5587, Training accuracy: 0.8050
# Validation loss: 0.8624, Validation accuracy: 0.7266
# Saving ...
#
# Epoch 9:
# Training loss: 0.5118, Training accuracy: 0.8204
# Validation loss: 0.9727, Validation accuracy: 0.7114
#
# Epoch 10:
# Training loss: 0.4607, Training accuracy: 0.8385
# Validation loss: 1.0836, Validation accuracy: 0.6770
# Validation loss: 1.5891, Validation accuracy: 0.7946
# Saving ...
#
# Epoch 61:
# Training loss: 0.0005, Training accuracy: 1.0000
# Validation loss: 1.6017, Validation accuracy: 0.7952
# Saving ...
#
# Epoch 62:
# Training loss: 0.0003, Training accuracy: 1.0000
# Validation loss: 1.5783, Validation accuracy: 0.7980
# Saving ...
#
# Epoch 63:
# Training loss: 0.0002, Training accuracy: 1.0000
# Validation loss: 1.5796, Validation accuracy: 0.7962
#
# Epoch 64:
# Training loss: 0.0002, Training accuracy: 1.0000
# Validation loss: 1.5845, Validation accuracy: 0.7960
#
# Epoch 65:
# Training loss: 0.0002, Training accuracy: 1.0000
# Validation loss: 1.5866, Validation accuracy: 0.7942
#
# Epoch 66:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5894, Validation accuracy: 0.7980
#
# Epoch 67:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5840, Validation accuracy: 0.7972
#
# Epoch 68:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5762, Validation accuracy: 0.7990
# Saving ...
#
# Epoch 69:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5762, Validation accuracy: 0.7990
#
# Epoch 70:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5774, Validation accuracy: 0.7990
#
# Epoch 71:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5764, Validation accuracy: 0.7960
#
# Epoch 72:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5667, Validation accuracy: 0.8012
# Saving ...
#
# Epoch 73:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5784, Validation accuracy: 0.7996
#
# Epoch 74:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5650, Validation accuracy: 0.7980
#
# Epoch 75:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5707, Validation accuracy: 0.7982
#
# Epoch 76:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5651, Validation accuracy: 0.7968
#
# Epoch 77:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5716, Validation accuracy: 0.7978
#
# Epoch 78:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5672, Validation accuracy: 0.7974
#
# Epoch 79:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5685, Validation accuracy: 0.7964
#
# Epoch 80:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5626, Validation accuracy: 0.7986
#
# Epoch 81:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5625, Validation accuracy: 0.7976
#
# Epoch 82:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5532, Validation accuracy: 0.8000
#
# Epoch 83:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5582, Validation accuracy: 0.7978
#
# Epoch 84:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5514, Validation accuracy: 0.7994
#
# Epoch 85:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5507, Validation accuracy: 0.7972
#
# Epoch 86:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5505, Validation accuracy: 0.7972
#
# Epoch 87:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5429, Validation accuracy: 0.7998
#
# Epoch 88:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5424, Validation accuracy: 0.7986
#
# Epoch 89:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5524, Validation accuracy: 0.7956
#
# Epoch 90:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5471, Validation accuracy: 0.7968
#
# Epoch 91:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5411, Validation accuracy: 0.7968
#
# Epoch 92:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5363, Validation accuracy: 0.7964
#
# Epoch 93:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5322, Validation accuracy: 0.7972
#
# Epoch 94:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5408, Validation accuracy: 0.7980
#
# Epoch 95:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5253, Validation accuracy: 0.7982
#
# Epoch 96:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5238, Validation accuracy: 0.7988
#
# Epoch 97:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5284, Validation accuracy: 0.7996
#
# Epoch 98:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5329, Validation accuracy: 0.7968
#
# Epoch 99:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5205, Validation accuracy: 0.7974
#
# Epoch 100:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5276, Validation accuracy: 0.7962
#
# Current learning rate has decayed to 0.100000
# Epoch 101:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5092, Validation accuracy: 0.7968
#
# Current learning rate has decayed to 0.100000
# Epoch 102:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5136, Validation accuracy: 0.7976
#
# Current learning rate has decayed to 0.100000
# Epoch 103:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5100, Validation accuracy: 0.7980
#
# Current learning rate has decayed to 0.100000
# Epoch 104:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5083, Validation accuracy: 0.7970
#
# Current learning rate has decayed to 0.100000
# Epoch 105:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5129, Validation accuracy: 0.7962
#
# Current learning rate has decayed to 0.100000
# Epoch 106:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5070, Validation accuracy: 0.7984
#
# Current learning rate has decayed to 0.100000
# Epoch 107:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5123, Validation accuracy: 0.7968
#
# Current learning rate has decayed to 0.100000
# Epoch 108:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5033, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.100000
# Epoch 109:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.5020, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.100000
# Epoch 110:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4967, Validation accuracy: 0.7982
#
# Current learning rate has decayed to 0.100000
# Epoch 111:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4918, Validation accuracy: 0.7980
#
# Current learning rate has decayed to 0.100000
# Epoch 112:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4944, Validation accuracy: 0.7998
#
# Current learning rate has decayed to 0.100000
# Epoch 113:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4872, Validation accuracy: 0.7970
#
# Current learning rate has decayed to 0.100000
# Epoch 114:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4853, Validation accuracy: 0.7984
#
# Current learning rate has decayed to 0.100000
# Epoch 115:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4939, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.100000
# Epoch 116:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4850, Validation accuracy: 0.7970
#
# Current learning rate has decayed to 0.100000
# Epoch 117:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4838, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.100000
# Epoch 118:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4821, Validation accuracy: 0.7964
#
# Current learning rate has decayed to 0.100000
# Epoch 119:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4775, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.100000
# Epoch 120:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4819, Validation accuracy: 0.7962
#
# Current learning rate has decayed to 0.100000
# Epoch 121:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4718, Validation accuracy: 0.7990
#
# Current learning rate has decayed to 0.100000
# Epoch 122:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4773, Validation accuracy: 0.7988
#
# Current learning rate has decayed to 0.100000
# Epoch 123:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4797, Validation accuracy: 0.7968
#
# Current learning rate has decayed to 0.100000
# Epoch 124:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4760, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.100000
# Epoch 125:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4725, Validation accuracy: 0.7968
#
# Current learning rate has decayed to 0.100000
# Epoch 126:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4632, Validation accuracy: 0.7982
#
# Current learning rate has decayed to 0.100000
# Epoch 127:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4633, Validation accuracy: 0.7944
#
# Current learning rate has decayed to 0.100000
# Epoch 128:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4707, Validation accuracy: 0.7980
#
# Current learning rate has decayed to 0.100000
# Epoch 129:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4709, Validation accuracy: 0.7966
#
# Current learning rate has decayed to 0.100000
# Epoch 130:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4562, Validation accuracy: 0.7960
#
# Current learning rate has decayed to 0.100000
# Epoch 131:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4516, Validation accuracy: 0.7992
#
# Current learning rate has decayed to 0.100000
# Epoch 132:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4654, Validation accuracy: 0.7976
#
# Current learning rate has decayed to 0.100000
# Epoch 133:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4544, Validation accuracy: 0.7972
#
# Current learning rate has decayed to 0.100000
# Epoch 134:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4513, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.100000
# Epoch 135:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4592, Validation accuracy: 0.7958
#
# Current learning rate has decayed to 0.100000
# Epoch 136:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4505, Validation accuracy: 0.7968
#
# Current learning rate has decayed to 0.100000
# Epoch 137:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4488, Validation accuracy: 0.7984
#
# Current learning rate has decayed to 0.100000
# Epoch 138:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4450, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.100000
# Epoch 139:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4461, Validation accuracy: 0.7980
#
# Epoch 140:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4415, Validation accuracy: 0.7968
#
# Current learning rate has decayed to 0.010000
# Epoch 141:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4484, Validation accuracy: 0.7964
#
# Current learning rate has decayed to 0.010000
# Epoch 142:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4525, Validation accuracy: 0.7972
#
# Current learning rate has decayed to 0.010000
# Epoch 143:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4375, Validation accuracy: 0.7972
#
# Current learning rate has decayed to 0.010000
# Epoch 144:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4457, Validation accuracy: 0.7958
#
# Current learning rate has decayed to 0.010000
# Epoch 145:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4420, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.010000
# Epoch 146:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4398, Validation accuracy: 0.7990
#
# Current learning rate has decayed to 0.010000
# Epoch 147:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4415, Validation accuracy: 0.7964
#
# Current learning rate has decayed to 0.010000
# Epoch 148:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4431, Validation accuracy: 0.7980
#
# Current learning rate has decayed to 0.010000
# Epoch 149:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4497, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.010000
# Epoch 150:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4467, Validation accuracy: 0.7952
#
# Current learning rate has decayed to 0.010000
# Epoch 151:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4474, Validation accuracy: 0.7970
#
# Current learning rate has decayed to 0.010000
# Epoch 152:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4428, Validation accuracy: 0.7964
#
# Current learning rate has decayed to 0.010000
# Epoch 153:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4414, Validation accuracy: 0.7986
#
# Current learning rate has decayed to 0.010000
# Epoch 154:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4416, Validation accuracy: 0.7962
#
# Current learning rate has decayed to 0.010000
# Epoch 155:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4405, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.010000
# Epoch 156:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4483, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.010000
# Epoch 157:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4469, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.010000
# Epoch 158:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4418, Validation accuracy: 0.7966
#
# Current learning rate has decayed to 0.010000
# Epoch 159:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4417, Validation accuracy: 0.7964
#
# Current learning rate has decayed to 0.010000
# Epoch 160:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4457, Validation accuracy: 0.7970
#
# Current learning rate has decayed to 0.010000
# Epoch 161:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4396, Validation accuracy: 0.7980
#
# Current learning rate has decayed to 0.010000
# Epoch 162:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4374, Validation accuracy: 0.7962
#
# Current learning rate has decayed to 0.010000
# Epoch 163:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4423, Validation accuracy: 0.7966
#
# Current learning rate has decayed to 0.010000
# Epoch 164:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4484, Validation accuracy: 0.7950
#
# Current learning rate has decayed to 0.010000
# Epoch 165:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4396, Validation accuracy: 0.7968
#
# Current learning rate has decayed to 0.010000
# Epoch 166:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4467, Validation accuracy: 0.7950
#
# Current learning rate has decayed to 0.010000
# Epoch 167:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4466, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.010000
# Epoch 168:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4415, Validation accuracy: 0.7970
#
# Current learning rate has decayed to 0.010000
# Epoch 169:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4516, Validation accuracy: 0.7954
#
# Epoch 170:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4379, Validation accuracy: 0.7986
#
# Current learning rate has decayed to 0.001000
# Epoch 171:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4454, Validation accuracy: 0.7968
#
# Current learning rate has decayed to 0.001000
# Epoch 172:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4475, Validation accuracy: 0.7986
#
# Current learning rate has decayed to 0.001000
# Epoch 173:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4477, Validation accuracy: 0.7956
#
# Current learning rate has decayed to 0.001000
# Epoch 174:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4482, Validation accuracy: 0.7956
#
# Current learning rate has decayed to 0.001000
# Epoch 175:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4469, Validation accuracy: 0.7960
#
# Current learning rate has decayed to 0.001000
# Epoch 176:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4384, Validation accuracy: 0.7976
#
# Current learning rate has decayed to 0.001000
# Epoch 177:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4354, Validation accuracy: 0.7970
#
# Current learning rate has decayed to 0.001000
# Epoch 178:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4372, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.001000
# Epoch 179:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4499, Validation accuracy: 0.7976
#
# Current learning rate has decayed to 0.001000
# Epoch 180:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4364, Validation accuracy: 0.7970
#
# Current learning rate has decayed to 0.001000
# Epoch 181:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4379, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.001000
# Epoch 182:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4428, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.001000
# Epoch 183:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4404, Validation accuracy: 0.7972
#
# Current learning rate has decayed to 0.001000
# Epoch 184:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4435, Validation accuracy: 0.7974
#
# Current learning rate has decayed to 0.001000
# Epoch 185:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4436, Validation accuracy: 0.7964
#
# Current learning rate has decayed to 0.001000
# Epoch 186:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4407, Validation accuracy: 0.7972
#
# Current learning rate has decayed to 0.001000
# Epoch 187:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4470, Validation accuracy: 0.7966
#
# Current learning rate has decayed to 0.001000
# Epoch 188:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4424, Validation accuracy: 0.7984
#
# Current learning rate has decayed to 0.001000
# Epoch 189:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4389, Validation accuracy: 0.7972
#
# Current learning rate has decayed to 0.001000
# Epoch 190:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4434, Validation accuracy: 0.7964
#
# Current learning rate has decayed to 0.001000
# Epoch 191:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4461, Validation accuracy: 0.7952
#
# Current learning rate has decayed to 0.001000
# Epoch 192:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4456, Validation accuracy: 0.7958
#
# Current learning rate has decayed to 0.001000
# Epoch 193:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4519, Validation accuracy: 0.7972
#
# Current learning rate has decayed to 0.001000
# Epoch 194:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4360, Validation accuracy: 0.7972
#
# Current learning rate has decayed to 0.001000
# Epoch 195:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4431, Validation accuracy: 0.7980
#
# Current learning rate has decayed to 0.001000
# Epoch 196:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4459, Validation accuracy: 0.7994
#
# Current learning rate has decayed to 0.001000
# Epoch 197:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4425, Validation accuracy: 0.7978
#
# Current learning rate has decayed to 0.001000
# Epoch 198:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4348, Validation accuracy: 0.7984
#
# Current learning rate has decayed to 0.001000
# Epoch 199:
# Training loss: 0.0001, Training accuracy: 1.0000
# Validation loss: 1.4472, Validation accuracy: 0.7972
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8012

# %% [markdown]
# **Now trying there way**

# %%
import itertools
import torchvision.transforms as trn
import cv2
import torchvision.transforms.functional as trnF
import opencv_functional as cv2f

expanded_params = ((0, -56, 56), (0, -56, 56))

shift = np.cumsum([0] + [len(p) for p in expanded_params[:-1]]).tolist()
num_params = [len(expanded_params[i]) for i in range(len(expanded_params))]
n_p1, n_p2 = num_params[0], num_params[1]
output_dim = sum(num_params) + 4  # +4 due to four rotations

pert_configs = []
for tx, ty in itertools.product(*expanded_params):
    pert_configs.append((tx, ty))

num_perts = len(pert_configs)

resize_and_crop = trn.Compose([trn.Resize(256), trn.RandomCrop(224)])


class PerturbDataset(torch.utils.data.Dataset):

    def __init__(self, dataset, train_mode=True):
        self.dataset = dataset
        self.train_mode = train_mode

    def __getitem__(self, index):
        x, _ = self.dataset[index // num_perts]
        pert = pert_configs[index % num_perts]

        x = np.asarray(resize_and_crop(x))

        if np.random.uniform() < 0.5:
            x = x[:, ::-1]
        x = cv2f.affine(np.asarray(x), 0, (pert[0], pert[1]), 1, 0,
                        interpolation=cv2.INTER_LINEAR, mode=cv2.BORDER_REFLECT_101)

        label = [expanded_params[i].index(pert[i]) for i in range(len(expanded_params))]
        label = np.vstack((label + [0], label + [1], label + [2], label + [3]))

        x = trnF.to_tensor(x.copy()).unsqueeze(0).numpy()
        x = np.concatenate((x, np.rot90(x, 1, axes=(2, 3)),
                            np.rot90(x, 2, axes=(2, 3)), np.rot90(x, 3, axes=(2, 3))), 0)

        return torch.FloatTensor(x), label
